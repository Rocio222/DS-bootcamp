# %% [markdown]
# # Funciónes

# %%
import numpy as np 
import matplotlib.pyplot as plt
import math 
from sympy import *

# %% [markdown]
# ### Grafica la función del coseno para el rango de -10 a 10

# %%
x = np.linspace(-10,10,200)
fx=np.cos(x)
plt.plot(x,fx)

# %% [markdown]
# ### Grafica una función simétrica

# %%
x = np.linspace(-2,2,100)
fx= x**4 -3*(x**2) +4
plt.plot(x,fx)

# %% [markdown]
# ## Calcula la derivada de la siguiente ecuación:
#
# $$ sin(x^2)+10 $$

# %%
x = Symbol("x")
eq = sin(x**2)+10
Derivative(eq,x).doit()
# Out:
# 2*x*cos(x**2)

# %% [markdown]
# ### Dada la siguiente función:
# $$x^2+10x+1 = 0$$
# Genera la grafica de la función, encuentra su derivada y muestra la recta tangente de la derivada en el punto x=-7.5

# %%
x = np.linspace(-30,30,100)
fx= x**2 + 10*x +1
#Escojo un punto para x y sustituyo para ver y(x=20)
plt.plot(20, 601, marker="o")
#m es derivada de la ecuacion en el valor x=20
m=2*20
y=m*x -m*20 + 601
plt.plot(x,y)
plt.plot(x,fx)
plt.xlim(-50,50)
plt.ylim(-1500,1500)
# Out:
# (-1500.0, 1500.0)
