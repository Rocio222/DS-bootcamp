# %% [markdown]
# ## Practica condicionales

# %%
# Ejemplo para pedir al usuario que ingrese un valor, 
#El valor ingresado por el usuario se guarda en la variable "x"
x = input("Ingresar el valor de x: ")
print("El valor de x es:",x)
print(type(x))
# Out:
# Ingresar el valor de x: 500
# El valor de x es: 500
# <class 'str'>

# %%
x=int(x)
type(x)
# Out:
# int

# %%
x = float(x)
type(x)
# Out:
# float

# %%
x+45
# Out:
# 545.0

# %%
# Si queremos cambiar el tipo de x de str a integer utilizamos la función int()
x = input("Ingresar el valor de x: ")
x=int(x)
print("El valor de x es:",x )
print(type(x))
# Out:
# Ingresar el valor de x: 475
# El valor de x es: 475
# <class 'int'>

# %% [markdown]
# ### Ejercicio 1

# %% [markdown]
# - Pedir al usuario que ingrese un número, imprimir si el número es par o impar

# %%
numero=int(input("escribe un numero"))
if numero%2==0:
    print("Tu numero es par")
else:
    print("Tu numero es impar")
# Out:
# escribe un numero43
# Tu numero es impar

# %% [markdown]
# ### Ejercicio 2

# %% [markdown]
# - Pedir al usuario que ingrese una frase. Contar el número de palabras. si el número de palabras es impar imprimir "El número de palabras es impar" de lo contrario imprimir "El número de palabras es par.

# %%
frase= input("escribe una frase: ")
lista_palabras= frase.split(" ")
if len(lista_palabras)%2==0:
    print("Tu frase tiene palabras pares")
else:
    print("Tu frase tiene palabras impares")
# Out:
# escribe una fraseeh lo no
# Tu frase tiene palabras impares

# %% [markdown]
# ### Ejercicio 3

# %% [markdown]
# #### EJEMPLO

# %% [markdown]
# - En la siguiente imagen tenemos las caracteristicas de un Chow Chow, vamos a utilizar condicionales para identificar si tu perro es un Chow Chow

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
altura = input("Ingrese altura del perro: ")
altura = int(altura)
peso = input("Ingrese peso del perro: ")
peso = int(peso)
pelo = input("Ingrese color del pelo del perro: ")
# Out:
# Ingrese altura del perro: 30
# Ingrese peso del perro: 25
# Ingrese color del pelo del perro: cafe

# %%
if (45<altura<55) & (25<peso<30):
    if (pelo=="negro") |  (pelo=="rojo") | (pelo=="crema"):
        print("Es un Chow Chow")
    else:
        print("No es un Chow Chow")
else:
    print("No es un Chow Chow")
# Out:
# No es un Chow Chow

# %% [markdown]
# - Crear los condicionales para identificar la raza entre los siguientes perros:
#
#     1. Encontrar las caracteristicas que comparten para poder decidir de acuerdo a esas caracteristicas de que raza se trata el perro

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
altura = int(input("Ingrese altura del perro: "))
altura = int(altura)
peso = int(input("Ingrese peso del perro: "))
pelo = input("Ingrese color del pelo del perro: ")

if (45<altura<55) & (25<peso<30):
    if (pelo=="negro") |  (pelo=="rojo") | (pelo=="crema"):
        print("Es un Chow Chow")
    else: 
        print("no es una raza conocida")
        
elif (50<altura<61) & (peso==20):
        if (pelo=="con manchas") | (pelo=="nace sin manchas"):
                print("Es un dalmata")
        else:
            print("No es una raza conocida")

elif (3<peso<10) & (altura<45 or altura>61): 
        if (pelo=="marron"):
            print("Es un Teckel")
        else:
            print("No es una raza conocida")
else:
    print("no es ninguna de las 3 razas")
# Out:
# Ingrese altura del perro: 300
# Ingrese peso del perro: 600
# Ingrese color del pelo del perro: uny
# no es ninguna de las 3 razas

# %% [markdown]
# ### Ejercicio 4

# %% [markdown]
# - Dada la siguiente imagen crear un conjunto de condicionales para imprimir el rango dado el índice de masa corporal. Para desarrollar el siguiente ejercicio, realiza los siguientes pasos:
#
#
# 1. Pedir el peso del usuario
# 2. Pedir la altura al usuario
# 3. Calcular el IMC (índice de masa corporal)
# 4. Crear los condicionales

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
peso= float(input("Escribe aqui tu peso: "))
altura= float (input("Escribe aqui tu altura en cm "))
imc= peso/altura**2
if imc<15:
    print("Delgadez muy severa")
elif (15>imc>15.9):
    print("Delgadez severa")
elif (16>imc>18.4):
    print("Delgadez")
elif (18.5>imc>24.9):
    print("Peso saludable")
elif (25>imc>29.9):
    print("Sobrepeso")
elif(30>imc>34.9):
    print("Obesidad Moderada")
elif(35>imc>39.9):
    print("Obesidad Severa")
else:
    print("Obesidad muy severa (Morbida)")
# Out:
# Escribe aqui tu peso: 45
# Escribe aqui tu altura en cm 170
# Delgadez muy severa

# %% [markdown]
# ### Ejercicio 5

# %% [markdown]
# - Vamos a calcular el Filtrado glomerular de una persona, lo cual nos va a servir para saber si una persona sufre de insuficiencia renal crónica, a partir de la ecuación mostrada en la imagén

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#min(scr/k,1)**alpha
min(0.7/0.9,1)**0.329
# Out:
# 0.9206434539849494

# %%
mn=min(Scr/k,1)
mx=max(Scr/k,1)
fg=141*(mn**alpha)*(mx**(-1.209))*(0.993**edad)

# %% [markdown]
# - Una vez creada la ecuación, se va agregar el código necesario para pedirle al usuario que agregue la siguiente información:
# 1. Edad
# 2. Sexo
# 3. Si es Afroamericano
# 4. Creatinina (el valor de la creatinina debe de rondar entre 0.7 y 2
#
# Y el resultado del código será el valor del filtrado glomerular

# %%
edad= int(input("Escribe aqui tu edad"))
sexo= input("Escribe aqui tu sexo")
afro= input("¿Eres afroamericano?")
scr=float(input("Nivel de creatinina"))

if sexo=="mujer" and afro=="no":
    k=0.7
    alpha=0.329
    mn=min(scr/k,1)
    mx=max(scr/k,1)
    fg=141*(mn**alpha)*(mx**(-1.209))*(0.993**edad)*1.018
    
if sexo=="mujer" and afro=="si":
    k=0.7
    alpha=0.329
    mn=min(scr/k,1)
    mx=max(scr/k,1)
    fg=141*(mn**alpha)*(mx**(-1.209))*(0.993**edad)*1.018*1.159
if sexo=="hombre" and afro=="no":
    k=0.9
    alpha=0.411
    mn=min(scr/k,1)
    mx=max(scr/k,1)
    fg=141*(mn**alpha)*(mx**(-1.209))*(0.993**edad)
if sexo=="hombre" and afro=="si":
    k=0.9
    alpha=0.411
    mn=min(scr/k,1)
    mx=max(scr/k,1)
    fg=141*(mn**alpha)*(mx**(-1.209))*(0.993**edad)*1.159
print("fg: ",fg)

if fg<15:
    print("Fallo renal")
if 15<fg<30:
    print("Gravemente disminuido")
if 30<fg<45:
    print("Moderada o gravemente disminuido")
if 45<fg<60:
    print("Ligera a moderadamente disminuido")
if 60<fg<90:
    print("Ligeramente disminuido")
if fg>90:
    print("Normal o elevado")
# Out:
# Escribe aqui tu edad80
# Escribe aqui tu sexomujer
# ¿Eres afroamericano?si
# Nivel de creatinina1.8
# fg:  30.275357349414577
# Moderada o gravemente disminuido

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Después de haber obtenido el filtrado glomerular vamos a obtener la valoración con la información de la siguiente tabla

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Podras comprobar el funcionamiento de tu programa en el siguiente link: http://www.semergencantabria.org/calc/cucalc2.htm
