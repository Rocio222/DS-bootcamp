# %%
#client_id= 21UB4FAQF0AZEJAOSR1WX1PCP0PQEBIU32IIBSBMDH0VASDO
#client_secret= 5WHV3LYBEZMIH3WYM2DUNZTNWKOABVUNYGF0A1SUS4Z4DAKL

# %%
import requests 
import pandas as pd 
import numpy as np 
import random 
import folium 
from geopy.geocoders import Nominatim

# %%
CLIENT_ID = '21UB4FAQF0AZEJAOSR1WX1PCP0PQEBIU32IIBSBMDH0VASDO' # ID
CLIENT_SECRET = '5WHV3LYBEZMIH3WYM2DUNZTNWKOABVUNYGF0A1SUS4Z4DAKL' # Secret ID
VERSION = '20190101'
LIMIT = 30

# %% [markdown]
# ## Parte 1

# %% [markdown]
# Convertir la dirección donde vives en longitud y latitud y buscar los restaurantes de comida italiana más cercanos a 3000 metros.

# %%
address = 'Jose Barbastre, Madrid 28017, Spain'

geolocator = Nominatim(user_agent="foursquare_agent") #A través de foursquare transforma la dirección en latitud y longitud
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 40.428361 -3.6516687

# %%
search_query = 'Italian food'
radius = 3000

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=21UB4FAQF0AZEJAOSR1WX1PCP0PQEBIU32IIBSBMDH0VASDO&client_secret=5WHV3LYBEZMIH3WYM2DUNZTNWKOABVUNYGF0A1SUS4Z4DAKL&ll=40.428361,-3.6516687&v=20190101&query=Italian food&radius=3000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5f2c19da407e0717624fd24b'},
#  'response': {'venues': [{'id': '57dabf83498e545077e1e0aa',
#     'name': 'Italiano Diablo Tattoo Studio',
#     'location': {'address': 'Calle de Sancho Dávila, 7',
#      'lat': 40.42834,
#      'lng': -3.661946,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.42834,
#        'lng': -3.661946}],
#      'distance': 870,
#      'postalCode': '28028',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Calle de Sancho Dávila, 7',
#       '28028 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d1de931735',
#       'name': 'Tattoo Parlor',
#       'pluralName': 'Tattoo Parlors',
#       'shortName': 'Tattoo',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/tattoos_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1596725718',
#     'hasPerk': False},
#    {'id': '4c3600f066e40f47e70bcc8b',
#     'name': 'Sabri Food Store',
#     'location': {'address': 'San Emilio 4',
#      'lat': 40.429075,
#      'lng': -3.658143,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.429075,
#        'lng': -3.658143}],
#      'distance': 554,
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['San Emilio 4', 'Madrid Madrid', 'España']},
#     'categories': [{'id': '4bf58dd8d48988d118951735',
#       'name': 'Grocery Store',
#       'pluralName': 'Grocery Stores',
#       'shortName': 'Grocery Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1596725718',
#     'hasPerk': False},
#    {'id': '54f882af498e3ac3f2f03542',
#     'name': 'Lemmes the Good Food, Take Away, Delivery',
#     'location': {'address': 'Padilla, 31',
#      'crossStreet': 'General pardiñas',
#      'lat': 40.431359,
#      'lng': -3.678308,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.431359,
#        'lng': -3.678308}],
#      'distance': 2281,
#      'postalCode': '28006',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Padilla, 31 (General pardiñas)',
#       '28006 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d1f9941735',
#       'name': 'Food & Drink Shop',
#       'pluralName': 'Food & Drink Shops',
#       'shortName': 'Food & Drink',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/foodanddrink_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1596725718',
#     'hasPerk': False},
#    {'id': '4f2fcd49e4b062ad2d714815',
#     'name': 'Ecome Food',
#     'location': {'address': 'C. Emilio Muñoz, 15',
#      'lat': 40.431286464230915,
#      'lng': -3.6294078366881273,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.431286464230915,
#        'lng': -3.6294078366881273}],
#      'distance': 1914,
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['C. Emilio Muñoz, 15', 'Madrid Madrid', 'España']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1596725718',
#     'hasPerk': False},
#    {'id': '55352493498ea9b86065290e',
#     'name': 'Food@Life, Panaderia y Tienda Ecologica',
#     'location': {'address': 'Lopez de Hoyos 81',
#      'lat': 40.44425673075245,
#      'lng': -3.6743581295013423,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.44425673075245,
#        'lng': -3.6743581295013423}],
#      'distance': 2612,
#      'postalCode': '28002',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Lopez de Hoyos 81',
#       '28002 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '126681601'},
#     'referralId': 'v-1596725718',
#     'hasPerk': False},
#    {'id': '4f38f659e4b02a70e2cf0e1e',
#     'name': 'como como slow food',
#     'location': {'address': 'C. Julián Camarillo, 47',
#      'crossStreet': 'C. San Sotero',
#      'lat': 40.43669237401987,
#      'lng': -3.6224176280777276,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.43669237401987,
#        'lng': -3.6224176280777276}],
#      'distance': 2646,
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['C. Julián Camarillo, 47 (C. San Sotero)',
#       'Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1596725718',
#     'hasPerk': False},
#    {'id': '55df0d4f498e82a12a8ec175',
#     'name': 'Neco Mediterranean Food',
#     'location': {'address': 'Avenida de Felipe II',
#      'lat': 40.423904225344884,
#      'lng': -3.6748890604982716,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.423904225344884,
#        'lng': -3.6748890604982716}],
#      'distance': 2029,
#      'postalCode': '28009',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Avenida de Felipe II',
#       '28009 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '52e81612bcbc57f1066b79f4',
#       'name': 'Buffet',
#       'pluralName': 'Buffets',
#       'shortName': 'Buffet',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1596725718',
#     'hasPerk': False},
#    {'id': '547c89cf498e02f12ddc449e',
#     'name': 'JGF fresh and fast food',
#     'location': {'address': 'Goya 113',
#      'lat': 40.42458,
#      'lng': -3.672281,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.42458,
#        'lng': -3.672281}],
#      'distance': 1796,
#      'postalCode': '28004',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Goya 113', '28004 Madrid Madrid', 'España']},
#     'categories': [{'id': '4bf58dd8d48988d1bd941735',
#       'name': 'Salad Place',
#       'pluralName': 'Salad Places',
#       'shortName': 'Salad',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/salad_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1596725718',
#     'hasPerk': False},
#    {'id': '4da0b406540ea1cd1dd956de',
#     'name': 'Panela & CO',
#     'location': {'address': 'C. López de Hoyos, 10',
#      'crossStreet': 'C. Serrano',
#      'lat': 40.436981631476385,
#      'lng': -3.6872125671178497,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.436981631476385,
#        'lng': -3.6872125671178497}],
#      'distance': 3160,
#      'postalCode': '28006',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['C. López de Hoyos, 10 (C. Serrano)',
#       '28006 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d179941735',
#       'name': 'Bagel Shop',
#       'pluralName': 'Bagel Shops',
#       'shortName': 'Bagels',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bagels_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1596725718',
#     'hasPerk': False},
#    {'id': '573739b5498e4cfe923d0491',
#     'name': 'Food Truck Colmenar',
#     'location': {'lat': 40.42505768460749,
#      'lng': -3.6685949510944207,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.42505768460749,
#        'lng': -3.6685949510944207}],
#      'distance': 1480,
#      'cc': 'ES',
#      'country': 'España',
#      'formattedAddress': ['España']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1596725718',
#     'hasPerk': False},
#    {'id': '57aa3365498e4c17262d1507',
#     'name': 'Street Food Terrace by Novotel',
#     'location': {'address': 'Calle de Albacete, 1',
#      'lat': 40.441316,
#      'lng': -3.657522,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.441316,
#        'lng': -3.657522}],
#      'distance': 1525,
#      'postalCode': '28027',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Calle de Albacete, 1',
#       '28027 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1596725718',
#     'hasPerk': False},
#    {'id': '5800db4ad67cbc46e4261e0a',
#     'name': 'lai fushion food',
#     'location': {'address': 'Clara del rey 24',
#      'lat': 40.44279,
#      'lng': -3.669739,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.44279,
#        'lng': -3.669739}],
#      'distance': 2219,
#      'postalCode': '28002',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Clara del rey 24',
#       '28002 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1596725718',
#     'hasPerk': False},
#    {'id': '50dc2889e4b0ab7ccc13f8ed',
#     'name': 'Food Truck',
#     'location': {'address': 'C. General Ricardos, 125',
#      'lat': 40.42458049950837,
#      'lng': -3.6706400791954756,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.42458049950837,
#        'lng': -3.6706400791954756}],
#      'distance': 1661,
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['C. General Ricardos, 125',
#       'Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1596725718',
#     'hasPerk': False},
#    {'id': '5c76749d31ac6c00394c3e4a',
#     'name': 'Cabaña Food Bar',
#     'location': {'address': 'calle don Ramon de la cruz 97 28006',
#      'lat': 40.42876993720913,
#      'lng': -3.6747349798679347,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.42876993720913,
#        'lng': -3.6747349798679347}],
#      'distance': 1955,
#      'postalCode': '28006',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['calle don Ramon de la cruz 97 28006',
#       '28006 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '56aa371be4b08b9a8d573558',
#       'name': 'Venezuelan Restaurant',
#       'pluralName': 'Venezuelan Restaurants',
#       'shortName': 'Venezuelan',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/argentinian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1596725718',
#     'hasPerk': False},
#    {'id': '5bfdbb15c36588002c38350c',
#     'name': 'Enriqueta Fresh Food Truck',
#     'location': {'address': 'Lopez de Hoyos',
#      'crossStreet': '42',
#      'lat': 40.44041496678215,
#      'lng': -3.6810341477394104,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.44041496678215,
#        'lng': -3.6810341477394104}],
#      'distance': 2826,
#      'postalCode': '28006',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Lopez de Hoyos (42)',
#       '28006 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1596725718',
#     'hasPerk': False},
#    {'id': '594a67b598fbfc5655a5323d',
#     'name': 'Pic And Nic Food',
#     'location': {'address': 'Calle Clara del Rey 52',
#      'lat': 40.44593,
#      'lng': -3.667959,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.44593,
#        'lng': -3.667959}],
#      'distance': 2393,
#      'postalCode': '28002',
#      'cc': 'ES',
#      'neighborhood': 'Prosperidad',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Calle Clara del Rey 52',
#       '28002 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1596725718',
#     'hasPerk': False},
#    {'id': '53124595498e61dc12645e2a',
#     'name': 'American Dinner Food Truck',
#     'location': {'address': 'Calle de Monte Esquinza, 39',
#      'lat': 40.43019654621546,
#      'lng': -3.679158210555216,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.43019654621546,
#        'lng': -3.679158210555216}],
#      'distance': 2338,
#      'postalCode': '28010',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Calle de Monte Esquinza, 39',
#       '28010 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d16c941735',
#       'name': 'Burger Joint',
#       'pluralName': 'Burger Joints',
#       'shortName': 'Burgers',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1596725718',
#     'hasPerk': False},
#    {'id': '58f4dca14acb19754be513e9',
#     'name': 'Planet Organic Food&Life',
#     'location': {'address': '63 Calle Castelló',
#      'lat': 40.428808,
#      'lng': -3.681333,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.428808,
#        'lng': -3.681333}],
#      'distance': 2514,
#      'postalCode': '28001',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['63 Calle Castelló',
#       '28001 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d1d3941735',
#       'name': 'Vegetarian / Vegan Restaurant',
#       'pluralName': 'Vegetarian / Vegan Restaurants',
#       'shortName': 'Vegetarian / Vegan',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1596725718',
#     'hasPerk': False},
#    {'id': '52d045ef498e738dd3c11c7c',
#     'name': 'Kyoto Gourmet Japan & Asian Food',
#     'location': {'address': 'C. Ayala, 65',
#      'lat': 40.427459,
#      'lng': -3.676833,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.427459,
#        'lng': -3.676833}],
#      'distance': 2134,
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['C. Ayala, 65', 'Madrid Madrid', 'España']},
#     'categories': [{'id': '4bf58dd8d48988d146941735',
#       'name': 'Deli / Bodega',
#       'pluralName': 'Delis / Bodegas',
#       'shortName': 'Deli / Bodega',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1596725718',
#     'hasPerk': False},
#    {'id': '4ead99d3775bad292f7bf0a0',
#     'name': 'Food Truck Martin',
#     'location': {'lat': 40.437763,
#      'lng': -3.631908,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.437763,
#        'lng': -3.631908}],
#      'distance': 1974,
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Madrid Madrid', 'España']},
#     'categories': [{'id': '4d4ae6fc7a7b7dea34424761',
#       'name': 'Fried Chicken Joint',
#       'pluralName': 'Fried Chicken Joints',
#       'shortName': 'Fried Chicken',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1596725718',
#     'hasPerk': False},
#    {'id': '57685c25498ee3f78cb522c5',
#     'name': 'Fit Food Velázquez 39',
#     'location': {'address': 'Velázquez 39',
#      'lat': 40.42603396100617,
#      'lng': -3.6841320991516113,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.42603396100617,
#        'lng': -3.6841320991516113}],
#      'distance': 2763,
#      'postalCode': '28002',
#      'cc': 'ES',
#      'city': 'madrid',
#      'state': 'madrdi',
#      'country': 'España',
#      'formattedAddress': ['Velázquez 39', '28002 madrid madrdi', 'España']},
#     'categories': [{'id': '4bf58dd8d48988d1d3941735',
#       'name': 'Vegetarian / Vegan Restaurant',
#       'pluralName': 'Vegetarian / Vegan Restaurants',
#       'shortName': 'Vegetarian / Vegan',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1596725718',
#     'hasPerk': False},
#    {'id': '53d1161d498eb9a206f47334',
#     'name': 'fit food',
#     'location': {'address': 'Calle Serrano 98',
#      'crossStreet': 'Juan Bravo',
#      'lat': 40.43345983913519,
#      'lng': -3.6868667365243777,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.43345983913519,
#        'lng': -3.6868667365243777}],
#      'distance': 3036,
#      'postalCode': '28006',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Calle Serrano 98 (Juan Bravo)',
#       '28006 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b41',
#       'name': 'Smoothie Shop',
#       'pluralName': 'Smoothie Shops',
#       'shortName': 'Smoothie Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/juicebar_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1596725718',
#     'hasPerk': False},
#    {'id': '54243b81498e0ccd92215778',
#     'name': 'Doki Doki',
#     'location': {'address': 'Calle Villalar, 4',
#      'lat': 40.42116858895287,
#      'lng': -3.689797446212131,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.42116858895287,
#        'lng': -3.689797446212131}],
#      'distance': 3328,
#      'postalCode': '28001',
#      'cc': 'ES',
#      'neighborhood': 'Recoletos',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Calle Villalar, 4',
#       '28001 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1596725718',
#     'hasPerk': False},
#    {'id': '5014307ae4b06bc0bdbde4de',
#     'name': 'Food&Drinks',
#     'location': {'address': 'Albasanz 72',
#      'lat': 40.43851045887761,
#      'lng': -3.6226979556104344,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.43851045887761,
#        'lng': -3.6226979556104344}],
#      'distance': 2702,
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Albasanz 72', 'Madrid Madrid', 'España']},
#     'categories': [{'id': '4bf58dd8d48988d1c2941735',
#       'name': 'Molecular Gastronomy Restaurant',
#       'pluralName': 'Molecular Gastronomy Restaurants',
#       'shortName': 'Molecular Gastronomy',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/moleculargastronomy_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1596725718',
#     'hasPerk': False},
#    {'id': '57f4b03b498e75c62f9e9bc5',
#     'name': 'Maura Wines & Food',
#     'location': {'address': 'Calle de Antonio Maura, 9',
#      'lat': 40.416713,
#      'lng': -3.690996,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.416713,
#        'lng': -3.690996}],
#      'distance': 3576,
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Calle de Antonio Maura, 9',
#       'Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1596725718',
#     'hasPerk': False},
#    {'id': '532d7469498e6f7a11b53ddc',
#     'name': 'Matteo Cucina Italiana',
#     'location': {'address': 'Calle Ayala 28',
#      'lat': 40.427054401800795,
#      'lng': -3.685701435792598,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.427054401800795,
#        'lng': -3.685701435792598}],
#      'distance': 2887,
#      'postalCode': '28001',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Calle Ayala 28', '28001 Madrid Madrid', 'España']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '101360180'},
#     'referralId': 'v-1596725718',
#     'hasPerk': False},
#    {'id': '5ee36a2aae69676d8157fa48',
#     'name': 'Technology Food Export',
#     'location': {'address': 'Calle del Príncipe de Vergara 136',
#      'lat': 40.4439584,
#      'lng': -3.67814814,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.4439584,
#        'lng': -3.67814814}],
#      'distance': 2836,
#      'postalCode': '28002',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Calle del Príncipe de Vergara 136',
#       '28002 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d1ff941735',
#       'name': 'Miscellaneous Shop',
#       'pluralName': 'Miscellaneous Shops',
#       'shortName': 'Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '588048250'},
#     'referralId': 'v-1596725718',
#     'hasPerk': False},
#    {'id': '5c6a922298fbfc002c9908fc',
#     'name': 'Selfie food and drinks',
#     'location': {'address': 'Núñez de Balboa 123',
#      'crossStreet': 'Maria de Molina',
#      'lat': 40.43723850728129,
#      'lng': -3.6818253993988033,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.43723850728129,
#        'lng': -3.6818253993988033}],
#      'distance': 2739,
#      'postalCode': '28006',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Núñez de Balboa 123 (Maria de Molina)',
#       '28006 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d150941735',
#       'name': 'Spanish Restaurant',
#       'pluralName': 'Spanish Restaurants',
#       'shortName': 'Spanish',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1596725718',
#     'hasPerk': False},
#    {'id': '55aa6da4498e15ff286cabd3',
#     'name': 'Kinua Peru Food',
#     'location': {'lat': 40.426151,
#      'lng': -3.688691,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.426151,
#        'lng': -3.688691}],
#      'distance': 3146,
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Madrid Madrid', 'España']},
#     'categories': [{'id': '4bf58dd8d48988d1be941735',
#       'name': 'Latin American Restaurant',
#       'pluralName': 'Latin American Restaurants',
#       'shortName': 'Latin American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/latinamerican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1596725718',
#     'hasPerk': False},
#    {'id': '5d0a86f3561a37002c2c056f',
#     'name': 'Graal Street Food',
#     'location': {'address': 'Avenida Del Mediterráneo 12',
#      'lat': 40.40737,
#      'lng': -3.676848,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.40737,
#        'lng': -3.676848}],
#      'distance': 3164,
#      'postalCode': '28007',
#      'cc': 'ES',
#      'city': 'Madrid',
#      'state': 'Madrid',
#      'country': 'España',
#      'formattedAddress': ['Avenida Del Mediterráneo 12',
#       '28007 Madrid Madrid',
#       'España']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1596725718',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']
#print(venues)
#tranform venues into a dataframe
dataframe = pd.json_normalize(venues)
dataframe.shape
# Out:
# (30, 19)

# %% [markdown]
# Obtener un dataframe con los nombres, categorías, dirección, codigo postal, latitud, longitud e ID.

# %%
dataframe.head(3)
# Out:
#                          id                                       name  \
# 0  57dabf83498e545077e1e0aa              Italiano Diablo Tattoo Studio
# 1  4c3600f066e40f47e70bcc8b                           Sabri Food Store
# 2  54f882af498e3ac3f2f03542  Lemmes the Good Food, Take Away, Delivery
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1de931735', 'name': 'T...  v-1596725718    False
# 1  [{'id': '4bf58dd8d48988d118951735', 'name': 'G...  v-1596725718    False
# 2  [{'id': '4bf58dd8d48988d1f9941735', 'name': 'F...  v-1596725718    False
#
#             location.address  location.lat  location.lng  \
# 0  Calle de Sancho Dávila, 7     40.428340     -3.661946
# 1               San Emilio 4     40.429075     -3.658143
# 2                Padilla, 31     40.431359     -3.678308
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 40.42834, 'lng': ...                870
# 1  [{'label': 'display', 'lat': 40.429075, 'lng':...                554
# 2  [{'label': 'display', 'lat': 40.431359, 'lng':...               2281
#
#   location.postalCode location.cc location.city location.state  \
# 0               28028          ES        Madrid         Madrid
# 1                 NaN          ES        Madrid         Madrid
# 2               28006          ES        Madrid         Madrid
#
#   location.country                          location.formattedAddress  \
# 0           España  [Calle de Sancho Dávila, 7, 28028 Madrid Madri...
# 1           España              [San Emilio 4, Madrid Madrid, España]
# 2           España  [Padilla, 31 (General pardiñas), 28006 Madrid ...
#
#   location.crossStreet venuePage.id location.neighborhood
# 0                  NaN          NaN                   NaN
# 1                  NaN          NaN                   NaN
# 2     General pardiñas          NaN                   NaN

# %%
#solamente dejamos las columnas name, categories, id y todas las que comienzan con "location"
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']

# %%
dataframe_filtered = dataframe.loc[:, filtered_columns]

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']    
    except:
        categories_list = row['venue.categories']    
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)
dataframe_filtered
# Out:
#                                          name  \
# 0               Italiano Diablo Tattoo Studio
# 1                            Sabri Food Store
# 2   Lemmes the Good Food, Take Away, Delivery
# 3                                  Ecome Food
# 4     Food@Life, Panaderia y Tienda Ecologica
# 5                         como como slow food
# 6                     Neco Mediterranean Food
# 7                     JGF fresh and fast food
# 8                                 Panela & CO
# 9                         Food Truck Colmenar
# 10             Street Food Terrace by Novotel
# 11                           lai fushion food
# 12                                 Food Truck
# 13                            Cabaña Food Bar
# 14                 Enriqueta Fresh Food Truck
# 15                           Pic And Nic Food
# 16                 American Dinner Food Truck
# 17                   Planet Organic Food&Life
# 18           Kyoto Gourmet Japan & Asian Food
# 19                          Food Truck Martin
# 20                      Fit Food Velázquez 39
# 21                                   fit food
# 22                                  Doki Doki
# 23                                Food&Drinks
# 24                         Maura Wines & Food
# 25                     Matteo Cucina Italiana
# 26                     Technology Food Export
# 27                     Selfie food and drinks
# 28                            Kinua Peru Food
# 29                          Graal Street Food
#
#                          categories                     location.address  \
# 0                     Tattoo Parlor            Calle de Sancho Dávila, 7
# 1                     Grocery Store                         San Emilio 4
# 2                 Food & Drink Shop                          Padilla, 31
# 3                        Restaurant                  C. Emilio Muñoz, 15
# 4                            Bakery                    Lopez de Hoyos 81
# 5                       Coffee Shop              C. Julián Camarillo, 47
# 6                            Buffet                 Avenida de Felipe II
# 7                       Salad Place                             Goya 113
# 8                        Bagel Shop                C. López de Hoyos, 10
# 9                        Food Truck                                  NaN
# 10                       Restaurant                 Calle de Albacete, 1
# 11                 Asian Restaurant                     Clara del rey 24
# 12                       Food Truck             C. General Ricardos, 125
# 13            Venezuelan Restaurant  calle don Ramon de la cruz 97 28006
# 14             Fast Food Restaurant                       Lopez de Hoyos
# 15                       Restaurant               Calle Clara del Rey 52
# 16                     Burger Joint          Calle de Monte Esquinza, 39
# 17    Vegetarian / Vegan Restaurant                    63 Calle Castelló
# 18                    Deli / Bodega                         C. Ayala, 65
# 19              Fried Chicken Joint                                  NaN
# 20    Vegetarian / Vegan Restaurant                         Velázquez 39
# 21                    Smoothie Shop                     Calle Serrano 98
# 22              Japanese Restaurant                    Calle Villalar, 4
# 23  Molecular Gastronomy Restaurant                          Albasanz 72
# 24                      Coffee Shop            Calle de Antonio Maura, 9
# 25               Italian Restaurant                       Calle Ayala 28
# 26               Miscellaneous Shop    Calle del Príncipe de Vergara 136
# 27               Spanish Restaurant                  Núñez de Balboa 123
# 28        Latin American Restaurant                                  NaN
# 29             Fast Food Restaurant          Avenida Del Mediterráneo 12
#
#     location.lat  location.lng  \
# 0      40.428340     -3.661946
# 1      40.429075     -3.658143
# 2      40.431359     -3.678308
# 3      40.431286     -3.629408
# 4      40.444257     -3.674358
# 5      40.436692     -3.622418
# 6      40.423904     -3.674889
# 7      40.424580     -3.672281
# 8      40.436982     -3.687213
# 9      40.425058     -3.668595
# 10     40.441316     -3.657522
# 11     40.442790     -3.669739
# 12     40.424580     -3.670640
# 13     40.428770     -3.674735
# 14     40.440415     -3.681034
# 15     40.445930     -3.667959
# 16     40.430197     -3.679158
# 17     40.428808     -3.681333
# 18     40.427459     -3.676833
# 19     40.437763     -3.631908
# 20     40.426034     -3.684132
# 21     40.433460     -3.686867
# 22     40.421169     -3.689797
# 23     40.438510     -3.622698
# 24     40.416713     -3.690996
# 25     40.427054     -3.685701
# 26     40.443958     -3.678148
# 27     40.437239     -3.681825
# 28     40.426151     -3.688691
# 29     40.407370     -3.676848
#
#                               location.labeledLatLngs  location.distance  \
# 0   [{'label': 'display', 'lat': 40.42834, 'lng': ...                870
# 1   [{'label': 'display', 'lat': 40.429075, 'lng':...                554
# 2   [{'label': 'display', 'lat': 40.431359, 'lng':...               2281
# 3   [{'label': 'display', 'lat': 40.43128646423091...               1914
# 4   [{'label': 'display', 'lat': 40.44425673075245...               2612
# 5   [{'label': 'display', 'lat': 40.43669237401987...               2646
# 6   [{'label': 'display', 'lat': 40.42390422534488...               2029
# 7   [{'label': 'display', 'lat': 40.42458, 'lng': ...               1796
# 8   [{'label': 'display', 'lat': 40.43698163147638...               3160
# 9   [{'label': 'display', 'lat': 40.42505768460749...               1480
# 10  [{'label': 'display', 'lat': 40.441316, 'lng':...               1525
# 11  [{'label': 'display', 'lat': 40.44279, 'lng': ...               2219
# 12  [{'label': 'display', 'lat': 40.42458049950837...               1661
# 13  [{'label': 'display', 'lat': 40.42876993720913...               1955
# 14  [{'label': 'display', 'lat': 40.44041496678215...               2826
# 15  [{'label': 'display', 'lat': 40.44593, 'lng': ...               2393
# 16  [{'label': 'display', 'lat': 40.43019654621546...               2338
# 17  [{'label': 'display', 'lat': 40.428808, 'lng':...               2514
# 18  [{'label': 'display', 'lat': 40.427459, 'lng':...               2134
# 19  [{'label': 'display', 'lat': 40.437763, 'lng':...               1974
# 20  [{'label': 'display', 'lat': 40.42603396100617...               2763
# 21  [{'label': 'display', 'lat': 40.43345983913519...               3036
# 22  [{'label': 'display', 'lat': 40.42116858895287...               3328
# 23  [{'label': 'display', 'lat': 40.43851045887761...               2702
# 24  [{'label': 'display', 'lat': 40.416713, 'lng':...               3576
# 25  [{'label': 'display', 'lat': 40.42705440180079...               2887
# 26  [{'label': 'display', 'lat': 40.4439584, 'lng'...               2836
# 27  [{'label': 'display', 'lat': 40.43723850728129...               2739
# 28  [{'label': 'display', 'lat': 40.426151, 'lng':...               3146
# 29  [{'label': 'display', 'lat': 40.40737, 'lng': ...               3164
#
#    location.postalCode location.cc location.city location.state  \
# 0                28028          ES        Madrid         Madrid
# 1                  NaN          ES        Madrid         Madrid
# 2                28006          ES        Madrid         Madrid
# 3                  NaN          ES        Madrid         Madrid
# 4                28002          ES        Madrid         Madrid
# 5                  NaN          ES        Madrid         Madrid
# 6                28009          ES        Madrid         Madrid
# 7                28004          ES        Madrid         Madrid
# 8                28006          ES        Madrid         Madrid
# 9                  NaN          ES           NaN            NaN
# 10               28027          ES        Madrid         Madrid
# 11               28002          ES        Madrid         Madrid
# 12                 NaN          ES        Madrid         Madrid
# 13               28006          ES        Madrid         Madrid
# 14               28006          ES        Madrid         Madrid
# 15               28002          ES        Madrid         Madrid
# 16               28010          ES        Madrid         Madrid
# 17               28001          ES        Madrid         Madrid
# 18                 NaN          ES        Madrid         Madrid
# 19                 NaN          ES        Madrid         Madrid
# 20               28002          ES        madrid         madrdi
# 21               28006          ES        Madrid         Madrid
# 22               28001          ES        Madrid         Madrid
# 23                 NaN          ES        Madrid         Madrid
# 24                 NaN          ES        Madrid         Madrid
# 25               28001          ES        Madrid         Madrid
# 26               28002          ES        Madrid         Madrid
# 27               28006          ES        Madrid         Madrid
# 28                 NaN          ES        Madrid         Madrid
# 29               28007          ES        Madrid         Madrid
#
#    location.country                          location.formattedAddress  \
# 0            España  [Calle de Sancho Dávila, 7, 28028 Madrid Madri...
# 1            España              [San Emilio 4, Madrid Madrid, España]
# 2            España  [Padilla, 31 (General pardiñas), 28006 Madrid ...
# 3            España       [C. Emilio Muñoz, 15, Madrid Madrid, España]
# 4            España   [Lopez de Hoyos 81, 28002 Madrid Madrid, España]
# 5            España  [C. Julián Camarillo, 47 (C. San Sotero), Madr...
# 6            España  [Avenida de Felipe II, 28009 Madrid Madrid, Es...
# 7            España            [Goya 113, 28004 Madrid Madrid, España]
# 8            España  [C. López de Hoyos, 10 (C. Serrano), 28006 Mad...
# 9            España                                           [España]
# 10           España  [Calle de Albacete, 1, 28027 Madrid Madrid, Es...
# 11           España    [Clara del rey 24, 28002 Madrid Madrid, España]
# 12           España  [C. General Ricardos, 125, Madrid Madrid, España]
# 13           España  [calle don Ramon de la cruz 97 28006, 28006 Ma...
# 14           España  [Lopez de Hoyos (42), 28006 Madrid Madrid, Esp...
# 15           España  [Calle Clara del Rey 52, 28002 Madrid Madrid, ...
# 16           España  [Calle de Monte Esquinza, 39, 28010 Madrid Mad...
# 17           España   [63 Calle Castelló, 28001 Madrid Madrid, España]
# 18           España              [C. Ayala, 65, Madrid Madrid, España]
# 19           España                            [Madrid Madrid, España]
# 20           España        [Velázquez 39, 28002 madrid madrdi, España]
# 21           España  [Calle Serrano 98 (Juan Bravo), 28006 Madrid M...
# 22           España   [Calle Villalar, 4, 28001 Madrid Madrid, España]
# 23           España               [Albasanz 72, Madrid Madrid, España]
# 24           España  [Calle de Antonio Maura, 9, Madrid Madrid, Esp...
# 25           España      [Calle Ayala 28, 28001 Madrid Madrid, España]
# 26           España  [Calle del Príncipe de Vergara 136, 28002 Madr...
# 27           España  [Núñez de Balboa 123 (Maria de Molina), 28006 ...
# 28           España                            [Madrid Madrid, España]
# 29           España  [Avenida Del Mediterráneo 12, 28007 Madrid Mad...
#
#    location.crossStreet location.neighborhood                        id
# 0                   NaN                   NaN  57dabf83498e545077e1e0aa
# 1                   NaN                   NaN  4c3600f066e40f47e70bcc8b
# 2      General pardiñas                   NaN  54f882af498e3ac3f2f03542
# 3                   NaN                   NaN  4f2fcd49e4b062ad2d714815
# 4                   NaN                   NaN  55352493498ea9b86065290e
# 5         C. San Sotero                   NaN  4f38f659e4b02a70e2cf0e1e
# 6                   NaN                   NaN  55df0d4f498e82a12a8ec175
# 7                   NaN                   NaN  547c89cf498e02f12ddc449e
# 8            C. Serrano                   NaN  4da0b406540ea1cd1dd956de
# 9                   NaN                   NaN  573739b5498e4cfe923d0491
# 10                  NaN                   NaN  57aa3365498e4c17262d1507
# 11                  NaN                   NaN  5800db4ad67cbc46e4261e0a
# 12                  NaN                   NaN  50dc2889e4b0ab7ccc13f8ed
# 13                  NaN                   NaN  5c76749d31ac6c00394c3e4a
# 14                   42                   NaN  5bfdbb15c36588002c38350c
# 15                  NaN           Prosperidad  594a67b598fbfc5655a5323d
# 16                  NaN                   NaN  53124595498e61dc12645e2a
# 17                  NaN                   NaN  58f4dca14acb19754be513e9
# 18                  NaN                   NaN  52d045ef498e738dd3c11c7c
# 19                  NaN                   NaN  4ead99d3775bad292f7bf0a0
# 20                  NaN                   NaN  57685c25498ee3f78cb522c5
# 21           Juan Bravo                   NaN  53d1161d498eb9a206f47334
# 22                  NaN             Recoletos  54243b81498e0ccd92215778
# 23                  NaN                   NaN  5014307ae4b06bc0bdbde4de
# 24                  NaN                   NaN  57f4b03b498e75c62f9e9bc5
# 25                  NaN                   NaN  532d7469498e6f7a11b53ddc
# 26                  NaN                   NaN  5ee36a2aae69676d8157fa48
# 27      Maria de Molina                   NaN  5c6a922298fbfc002c9908fc
# 28                  NaN                   NaN  55aa6da4498e15ff286cabd3
# 29                  NaN                   NaN  5d0a86f3561a37002c2c056f

# %%
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

# %% [markdown]
# En folium ubicar los restaurantes

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# aEl circulo rojo es el hotel
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# los circulos azules son los restaurantes
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Repetir los pasos anteriores con restaurantes de comida mexicana.

# %%
search_query = 'Mexican food'
radius = 3000

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=21UB4FAQF0AZEJAOSR1WX1PCP0PQEBIU32IIBSBMDH0VASDO&client_secret=5WHV3LYBEZMIH3WYM2DUNZTNWKOABVUNYGF0A1SUS4Z4DAKL&ll=40.428361,-3.6516687&v=20190101&query=Mexican food&radius=3000&limit=30'

# %%
results = requests.get(url).json()

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']
#print(venues)
#tranform venues into a dataframe
dataframe = pd.json_normalize(venues)
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)
dataframe_filtered.head()
# Out:
#                                         name         categories        lat  \
# 0                Mexican Factory Burrito Bar      Burrito Place  40.437485
# 1          Mexican's Besta Chef at Salamanca       Cocktail Bar  40.431097
# 2                           Sabri Food Store      Grocery Store  40.429075
# 3    Food@Life, Panaderia y Tienda Ecologica             Bakery  40.444257
# 4  Lemmes the Good Food, Take Away, Delivery  Food & Drink Shop  40.431359
#
#         lng                                     labeledLatLngs  distance  cc  \
# 0 -3.686225  [{'label': 'display', 'lat': 40.437485, 'lng':...      3099  ES
# 1 -3.673894  [{'label': 'display', 'lat': 40.4310967331239,...      1907  ES
# 2 -3.658143  [{'label': 'display', 'lat': 40.429075, 'lng':...       554  ES
# 3 -3.674358  [{'label': 'display', 'lat': 40.44425673075245...      2612  ES
# 4 -3.678308  [{'label': 'display', 'lat': 40.431359, 'lng':...      2281  ES
#
#   country                                   formattedAddress  \
# 0  España                                           [España]
# 1  España                                           [España]
# 2  España              [San Emilio 4, Madrid Madrid, España]
# 3  España   [Lopez de Hoyos 81, 28002 Madrid Madrid, España]
# 4  España  [Padilla, 31 (General pardiñas), 28006 Madrid ...
#
#              address    city   state postalCode       crossStreet  \
# 0                NaN     NaN     NaN        NaN               NaN
# 1                NaN     NaN     NaN        NaN               NaN
# 2       San Emilio 4  Madrid  Madrid        NaN               NaN
# 3  Lopez de Hoyos 81  Madrid  Madrid      28002               NaN
# 4        Padilla, 31  Madrid  Madrid      28006  General pardiñas
#
#   neighborhood                        id
# 0          NaN  56f2be9c498e349a052e9de9
# 1          NaN  50d8d9d7e4b0b55bd04bd02e
# 2          NaN  4c3600f066e40f47e70bcc8b
# 3          NaN  55352493498ea9b86065290e
# 4          NaN  54f882af498e3ac3f2f03542

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# aEl circulo rojo es el hotel
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# los circulos azules son los restaurantes
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Obtener la siguiente información de los primeros 3 restaurantes italianos y mexicanos: name, rating, likes y dislike y location, ordenarlos en un DataFrame.

# %%
dataframe_filtered.head(3)
# Out:
#                                 name     categories        lat       lng  \
# 0        Mexican Factory Burrito Bar  Burrito Place  40.437485 -3.686225
# 1  Mexican's Besta Chef at Salamanca   Cocktail Bar  40.431097 -3.673894
# 2                   Sabri Food Store  Grocery Store  40.429075 -3.658143
#
#                                       labeledLatLngs  distance  cc country  \
# 0  [{'label': 'display', 'lat': 40.437485, 'lng':...      3099  ES  España
# 1  [{'label': 'display', 'lat': 40.4310967331239,...      1907  ES  España
# 2  [{'label': 'display', 'lat': 40.429075, 'lng':...       554  ES  España
#
#                         formattedAddress       address    city   state  \
# 0                               [España]           NaN     NaN     NaN
# 1                               [España]           NaN     NaN     NaN
# 2  [San Emilio 4, Madrid Madrid, España]  San Emilio 4  Madrid  Madrid
#
#   postalCode crossStreet neighborhood                        id
# 0        NaN         NaN          NaN  56f2be9c498e349a052e9de9
# 1        NaN         NaN          NaN  50d8d9d7e4b0b55bd04bd02e
# 2        NaN         NaN          NaN  4c3600f066e40f47e70bcc8b

# %%
dataframe_filtered["id"][0]
# Out:
# '56f2be9c498e349a052e9de9'

# %%
names=[]
likes=[]
unlike=[]
location=[]
rating=[]
for i in range(7):
    venue_id=dataframe_filtered["id"][i]
    
    url='https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
    result = requests.get(url).json()
    names.append(result['response']['venue']['name'])
    likes.append(result['response']['venue']['likes']['count'])
    unlike.append(result['response']['venue']['dislike'])
    location.append(result['response']['venue']['location']['country'])
    try:
        rating.append(result['response']['venue']['rating'])
    except:
        rating.append("No hay rating")
df=pd.DataFrame(columns=["Names","Likes","Unlike","Location","Rating"])
df["Names"]=names
df["Likes"]=likes
df["Unlike"]=unlike
df["Location"]=location
df["Rating"]=rating

df
# Out:
#                                        Names  Likes  Unlike Location  \
# 0                Mexican Factory Burrito Bar      7   False   España
# 1          Mexican's Besta Chef at Salamanca      0   False   España
# 2                           Sabri Food Store      1   False   España
# 3    Food@Life, Panaderia y Tienda Ecologica      0   False   España
# 4  Lemmes the Good Food, Take Away, Delivery      3   False   España
# 5                        Food Truck Colmenar      0   False   España
# 6                    JGF fresh and fast food      2   False   España
#
#           Rating
# 0            7.5
# 1  No hay rating
# 2  No hay rating
# 3  No hay rating
# 4  No hay rating
# 5  No hay rating
# 6  No hay rating

# %% [markdown]
# ## Parte 2

# %% [markdown]
# Con la dirección donde vives obtener los primeros 50 venues más cercanos a tu dirección, Hacer un filtrado por la categoría que más se presenta y guardarlos en un dataframe. (Por ejemplo, si lo que más hay son Gimnasios, guardar esos gimnasios en un dataframe)

# %%
latitude = 40.428361
longitude = -3.6516687
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=21UB4FAQF0AZEJAOSR1WX1PCP0PQEBIU32IIBSBMDH0VASDO&client_secret=5WHV3LYBEZMIH3WYM2DUNZTNWKOABVUNYGF0A1SUS4Z4DAKL&ll=40.428361,-3.6516687&v=20190101&radius=3000&limit=30'

# %%
results = requests.get(url).json()
'Existen {} venues cerca de mi casa.'.format(len(results['response']['groups'][0]['items']))
# Out:
# 'Existen 30 venues cerca de mi casa.'

# %%
items=results["response"]["groups"][0]['items']

# %%
dataframe.columns
# Out:
# Index(['id', 'name', 'categories', 'referralId', 'hasPerk', 'location.lat',
#        'location.lng', 'location.labeledLatLngs', 'location.distance',
#        'location.cc', 'location.country', 'location.formattedAddress',
#        'location.address', 'location.city', 'location.state',
#        'location.postalCode', 'venuePage.id', 'location.crossStreet',
#        'location.neighborhood'],
#       dtype='object')

# %%
dataframe = pd.json_normalize(items) # pasamos el JSON a dataframe

# filtramos columnas
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filtramos la categoria para cada fila
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)
df=dataframe_filtered
df.head()
# Out:
#                              venue.name      venue.categories  \
# 0                       DreamFit Ventas                   Gym
# 1                               Docamar      Tapas Restaurant
# 2                             La Fornía                   Bar
# 3                 Crossfit Singular Box  Gym / Fitness Center
# 4  Parque Quinta de la Fuente del Berro                  Park
#
#    venue.location.lat  venue.location.lng  \
# 0           40.433099           -3.656662
# 1           40.433501           -3.648133
# 2           40.424986           -3.654087
# 3           40.427309           -3.662372
# 4           40.422644           -3.661108
#
#                        venue.location.labeledLatLngs  venue.location.distance  \
# 0  [{'label': 'display', 'lat': 40.43309946547303...                      676
# 1  [{'label': 'display', 'lat': 40.43350072361024...                      645
# 2  [{'label': 'display', 'lat': 40.42498557232842...                      428
# 3  [{'label': 'display', 'lat': 40.42730913124123...                      914
# 4  [{'label': 'display', 'lat': 40.42264446301398...                     1022
#
#   venue.location.cc venue.location.city venue.location.state  \
# 0                ES              Madrid               Madrid
# 1                ES              Madrid               Madrid
# 2                ES              Madrid               Madrid
# 3                ES              Madrid               Madrid
# 4                ES              Madrid               Madrid
#
#   venue.location.country                    venue.location.formattedAddress  \
# 0                 España                            [Madrid Madrid, España]
# 1                 España  [C. Alcalá, 337 (C. de la Argentina, 8), 28027...
# 2                 España  [C. Apóstol Santiago, 6, 28017 Madrid Madrid, ...
# 3                 España  [C. Ramón de Aguinaga, 13, 28028 Madrid Madrid...
# 4                 España  [C. Enrique de Almonte, 28028 Madrid Madrid, E...
#
#      venue.location.address venue.location.crossStreet  \
# 0                       NaN                        NaN
# 1            C. Alcalá, 337      C. de la Argentina, 8
# 2    C. Apóstol Santiago, 6                        NaN
# 3  C. Ramón de Aguinaga, 13                        NaN
# 4     C. Enrique de Almonte                        NaN
#
#   venue.location.postalCode venue.location.neighborhood  \
# 0                       NaN                         NaN
# 1                     28027                         NaN
# 2                     28017                         NaN
# 3                     28028                         NaN
# 4                     28028                         NaN
#
#                    venue.id
# 0  57752f64498e7468acd33cf5
# 1  4baf340af964a520ccf03be3
# 2  4c9bacb5292a6dcbb0bbd976
# 3  52f28465498e14c9371d7800
# 4  4adcda37f964a520153c21e3

# %%
df.groupby(['venue.categories']).count().idxmax()[0]
# Out:
# 'Bar'

# %%
df2=df[df['venue.categories']=='Bar']
df2
# Out:
#                      venue.name venue.categories  venue.location.lat  \
# 2                     La Fornía              Bar           40.424986
# 6           Cervecería Olivares              Bar           40.437265
# 7                    La Manduca              Bar           40.434422
# 8                    A'Conchiña              Bar           40.431764
# 13  El Callejón de Álvarez Gato              Bar           40.436425
#
#     venue.location.lng                      venue.location.labeledLatLngs  \
# 2            -3.654087  [{'label': 'display', 'lat': 40.42498557232842...
# 6            -3.650481  [{'label': 'display', 'lat': 40.43726454011188...
# 7            -3.659019  [{'label': 'display', 'lat': 40.43442200204738...
# 8            -3.650525  [{'label': 'display', 'lat': 40.43176391882853...
# 13           -3.644408  [{'label': 'display', 'lat': 40.43642507036786...
#
#     venue.location.distance venue.location.cc venue.location.city  \
# 2                       428                ES              Madrid
# 6                       996                ES              Madrid
# 7                       918                ES              Madrid
# 8                       391                ES              Madrid
# 13                     1088                ES              Madrid
#
#    venue.location.state venue.location.country  \
# 2                Madrid                 España
# 6                Madrid                 España
# 7                Madrid                 España
# 8                Madrid                 España
# 13               Madrid                 España
#
#                       venue.location.formattedAddress  \
# 2   [C. Apóstol Santiago, 6, 28017 Madrid Madrid, ...
# 6   [C. Virgen del Sagrario, 19 (C. Virgen de Nuri...
# 7   [Av. Donostiarra, 2-8, 28027 Madrid Madrid, Es...
# 8      [C. Benidorm, 32, 28017 Madrid Madrid, España]
# 13        [C. Elfo, 123, 28027 Madrid Madrid, España]
#
#         venue.location.address venue.location.crossStreet  \
# 2       C. Apóstol Santiago, 6                        NaN
# 6   C. Virgen del Sagrario, 19         C. Virgen de Nuria
# 7         Av. Donostiarra, 2-8                        NaN
# 8              C. Benidorm, 32                        NaN
# 13                C. Elfo, 123                        NaN
#
#    venue.location.postalCode    venue.location.neighborhood  \
# 2                      28017                            NaN
# 6                      28027  Ciudad Lineal, Madrid, Madrid
# 7                      28027                            NaN
# 8                      28017                            NaN
# 13                     28027                            NaN
#
#                     venue.id
# 2   4c9bacb5292a6dcbb0bbd976
# 6   4c4756041ddec9280e079d32
# 7   4bd88dbd51170f470ca033e4
# 8   4e24070cb0fbdf9ba7c32414
# 13  4b8c0dc0f964a52009bb32e3

# %% [markdown]
# Del dataframe anterior obtener name, rating y likes y seleccionar al que tiene más rating y más likes.

# %%
df["venue.location.lat"][0]
# Out:
# 40.43309946547303

# %%
for i in range(len(df)):
    latitude= df["venue.location.lat"][i]
    longitude= df["venue.location.lng"][i]
    url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)

# %% [markdown]
# En un Mapa mostrar los venues anteriores. (solamente los venues que comparten la misma categoría mayoritaria)
