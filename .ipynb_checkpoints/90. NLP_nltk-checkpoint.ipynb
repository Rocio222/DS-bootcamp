# %% [markdown]
# # NLTK

# %% [markdown]
# NLTK (Natural language tool kit) es un módulo de Python que contiene herramientas para el manejo del lenguaje natural. Para usarlas, al igual que con los otros módulos, se tiene que importar.

# %%
# conda install -c anaconda nltk 
import nltk

# %%
nltk.download() #Para descargar paquetes
# Models y descarguen punkt, que como verán, son modelos de tokenización
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
archivo_nombre="constitucion.txt"
with open(archivo_nombre,"r",  encoding='latin-1') as archivo: 
    texto=archivo.read()
print(texto)
# Out:
# El artículo 1 España se constituye en un Estado social y democrático de Derecho, que propugna como valores superiores de su ordenamiento jurídico la libertad, la justicia, la igualdad y el pluralismo político.
# El artículo 2 La Constitución se fundamenta en la indisoluble unidad de la Nación española, patria común e indivisible de todos los españoles, y reconoce y garantiza el derecho a la autonomía de las nacionalidades y regiones que la integran y la solidaridad entre todas ellas.
# Los artículos 3,3.4 El castellano es la lengua española oficial del Estado. Todos los españoles tienen el deber de conocerla y el derecho a usarla.
# El artículo 4 La bandera de España está formada por tres franjas horizontales, roja, amarilla y roja, siendo la amarilla de doble anchura que cada una de las rojas.
# El artículo 5 La capital del Estado es la villa de Madrid.
# El artículo 6 Los partidos políticos expresan el pluralismo político, concurren a la formación y manifestación de la voluntad popular y son instrumento fundamental para la participación política. Su creación y el ejercicio de su actividad son libres dentro del respeto a la Constitución y a la ley. Su estructura interna y funcionamiento deberán ser democráticos.

# %%
tokens=nltk.word_tokenize(texto,"spanish")
for token in tokens: 
    print(token)
# Out:
# El
# artículo
# 1
# España
# se
# constituye
# en
# un
# Estado
# social
# y
# democrático
# de
# Derecho
# ,
# que
# propugna
# como
# valores
# superiores
# de
# su
# ordenamiento
# jurídico
# la
# libertad
# ,
# la
# justicia
# ,
# la
# igualdad
# y
# el
# pluralismo
# político
# .
# El
# artículo
# 2
# La
# Constitución
# se
# fundamenta
# en
# la
# indisoluble
# unidad
# de
# la
# Nación
# española
# ,
# patria
# común
# e
# indivisible
# de
# todos
# los
# españoles
# ,
# y
# reconoce
# y
# garantiza
# el
# derecho
# a
# la
# autonomía
# de
# las
# nacionalidades
# y
# regiones
# que
# la
# integran
# y
# la
# solidaridad
# entre
# todas
# ellas
# .
# Los
# artículos
# 3,3.4
# El
# castellano
# es
# la
# lengua
# española
# oficial
# del
# Estado
# .
# Todos
# los
# españoles
# tienen
# el
# deber
# de
# conocerla
# y
# el
# derecho
# a
# usarla
# .
# El
# artículo
# 4
# La
# bandera
# de
# España
# está
# formada
# por
# tres
# franjas
# horizontales
# ,
# roja
# ,
# amarilla
# y
# roja
# ,
# siendo
# la
# amarilla
# de
# doble
# anchura
# que
# cada
# una
# de
# las
# rojas
# .
# El
# artículo
# 5
# La
# capital
# del
# Estado
# es
# la
# villa
# de
# Madrid
# .
# El
# artículo
# 6
# Los
# partidos
# políticos
# expresan
# el
# pluralismo
# político
# ,
# concurren
# a
# la
# formación
# y
# manifestación
# de
# la
# voluntad
# popular
# y
# son
# instrumento
# fundamental
# para
# la
# participación
# política
# .
# Su
# creación
# y
# el
# ejercicio
# de
# su
# actividad
# son
# libres
# dentro
# del
# respeto
# a
# la
# Constitución
# y
# a
# la
# ley
# .
# Su
# estructura
# interna
# y
# funcionamiento
# deberán
# ser
# democráticos
# .

# %%
palabras_total=len(tokens)
print(palabras_total)
# Out:
# 219

# %%
tokens_conjunto=set(tokens) 
palabras_diferentes=len(tokens_conjunto)
print(palabras_diferentes)
# Out:
# 121

# %% [markdown]
# La riqueza léxica es la relación que existe entre la extensión de un texto y el número de palabras distintas que contiene.

# %%
tokens_conjunto=set(tokens)
palabras_totales=len(tokens) 

palabras_diferentes=len(tokens_conjunto)

riqueza_lexica=palabras_diferentes/palabras_totales
print(riqueza_lexica)
# Out:
# 0.5525114155251142

# %%
#una alta riqueza lexica sería mayor a 0.7 

def riqueza_lexica(tokens): 
    tokens_conjunto=set(tokens)
    palabras_totales=len(tokens) 
    palabras_diferentes=len(tokens_conjunto)
    riqueza_lexica=palabras_diferentes/palabras_totales
    return riqueza_lexica

# %% [markdown]
# También podemos usar la lista de tokens para hacer conteos de palabras individuales.

# %%
#Count cuenta palabras dentro de tokens

conteo_individual=tokens.count("el")
print(conteo_individual)
# Out:
# 6

# %%
palabras_totales=len(tokens) 
porcentaje=100*conteo_individual/palabras_totales
print(porcentaje,"%")
# Out:
# 2.73972602739726 %

# %% [markdown]
# Las concordacias muestran todas las apariciones de una palabra junto del texto que la rodea.
#
# Con la función `concordance()` del Text de NLTK se muestran las concordancias de una palabra.

# %%
texto_nltk=nltk.Text(tokens) 
texto_nltk.concordance("artículo")
# Out:
# Displaying 5 of 5 matches:
# El artículo 1 España se constituye en un Estad
# ldad y el pluralismo político . El artículo 2 La Constitución se fundamenta en
# nocerla y el derecho a usarla . El artículo 4 La bandera de España está formad
# ura que cada una de las rojas . El artículo 5 La capital del Estado es la vill
#  Estado es la villa de Madrid . El artículo 6 Los partidos políticos expresan

# %%
with open("poe.txt","r", encoding='utf-8') as archivo: 
    texto=archivo.read() 
texto
# Out:
# "PRÓLOGO\n\n\nEn una mañana fría y húmeda llegué por primera vez al inmenso país de\nlos Estados Unidos. Iba el _steamer_ despacio, y la sirena aullaba\nroncamente por temor de un choque. Quedaba atrás Fire Island con su\nerecto faro; estábamos frente a Sandy Hook, de donde nos salió al paso\nel barco de sanidad. El ladrante slang yanqui sonaba por todas partes,\nbajo el pabellón de bandas y estrellas. El viento frío, los pitos\narromadizados, el humo de las chimeneas, el movimiento de las máquinas,\nlas mismas ondas ventrudas de aquel mar estañado, el vapor que caminaba\nrumbo a la gran bahía, todo decía: _all right_. Entre las brumas se\ndivisaban islas y barcos. Long Island desarrollaba la inmensa cinta de\nsus costas, y Staten Island, como en el marco de una viñeta, se\npresentaba en su hermosura, tentando al lápiz, ya que no, por falta de\nsol, a la máquina fotográfica. Sobre cubierta se agrupan los pasajeros:\nel comerciante de gruesa panza, congestionado como un pavo, con\nencorvadas narices israelitas; el clergyman huesoso, enfundado en su\nlargo levitón negro, cubierto con su ancho sombrero de fieltro, y en la\nmano una pequeña Biblia; la muchacha que usa gorra de jockey, y que\ndurante toda la travesía ha cantado con voz fonográfica, al són de un\nbanjo; el joven robusto, lampiño como un bebé, y que, aficionado al box,\ntiene los puños de tal modo, que bien pudiera desquijarrar un\nrinoceronte de un solo impulso... En los Narrows se alcanza a ver la\ntierra pintoresca y florida, las fortalezas. Luego, levantando sobre su\ncabeza la antorcha simbólica, queda a un lado la gigantesca Madona de la\nLibertad, que tiene por peana un islote. De mi alma brota entonces la\nsalutación:\n\n«A ti, prolífica, enorme, dominadora. A ti, Nuestra Señora de la\nLibertad. A ti, cuyas mamas de bronce alimentan un sinnúmero de almas y\ncorazones. A ti, que te alzas solitaria y magnífica sobre tu isla,\nlevantando la divina antorcha. Yo te saludo al paso de mi _steamer_,\nprosternándome delante de tu majestad. ¡Ave: Good morning! Yo sé, divino\nicono, ¡oh, magna estatua!, que tu solo nombre, el de la excelsa beldad\nque encarnas, ha hecho brotar estrellas sobre el mundo, a la manera del\n_fiat_ del Señor. Allí están entre todas, brillantes sobre las listas de\nla bandera, las que iluminan el vuelo del águila de América, de esta tu\nAmérica formidable, de ojos azules. Ave, Libertad, llena de fuerza; el\nSeñor es contigo: bendita tú eres. Pero, ¿sabes?, se te ha herido mucho\npor el mundo, divinidad, manchando tu esplendor. Anda en la tierra otra\nque ha usurpado tu nombre, y que, en vez de la antorcha, lleva la tea.\nAquélla no es la Diana sagrada de las incomparables flechas: es Hécate.»\n\nHecha mi salutación, mi vista contempla la masa enorme que está al\nfrente, aquella tierra coronada de torres, aquella región de donde casi\nsentís que viene un soplo subyugador y terrible: Manhattan, la isla de\nhierro, Nueva York, la sanguínea, la ciclópea, la monstruosa, la\ntormentosa, la irresistible capital del cheque. Rodeada de islas\nmenores, tiene cerca a Jersey; y agarrada a Brooklyn con la uña enorme\ndel puente, Brooklyn, que tiene sobre el palpitante pecho de acero un\nramillete de campanarios.\n\nSe cree oír la voz de Nueva York, el eco de un vasto soliloquio de\ncifras. ¡Cuán distinta de la voz de París, cuando uno cree escucharla,\nal acercarse, halagadora como una canción de amor, de poesía y de\njuventud! Sobre el suelo de Manhattan parece que va a verse surgir de\npronto un colosal Tío Samuel, que llama a los pueblos todos a un\ninaudito remate, y que el martillo del rematador cae sobre cúpulas y\ntechumbres produciendo un ensordecedor trueno metálico. Antes de entrar\nal corazón del monstruo, recuerdo la ciudad, que vio en el poema bárbaro\nel vidente Thogorma:\n\n_Thogorma dans ses yeux vit monter des murailles de fer dont\ns'enroulaient des spirales des tours et des palais cerclés d'arain sur\ndes blocs lourds; ruche énorme, géhe ...

# %%
tokens=nltk.word_tokenize(texto,"spanish")

# %%
len(tokens)
# Out:
# 13940

# %%
#la función nltk.Text nos convierte los tokens a un formato de texto de NLTK
texto_nltk=nltk.Text(tokens) 
texto_nltk.concordance("madre")
# Out:
# Displaying 7 of 7 matches:
#  de la mar quejumbrosa . 1849 . A MI MADRE ( _Soneto_ ) Porque siento que allá
#  , a ti que eres para mí más que una madre y que llenáis el santuario de mi cor
# libertar el alma de mi Virginia . Mi madre , mi propia madre , que murió en bue
# e mi Virginia . Mi madre , mi propia madre , que murió en buena hora , no era s
# murió en buena hora , no era sino mi madre . Pero vos fuisteis la madre de aque
# sino mi madre . Pero vos fuisteis la madre de aquella que quise tan tiernamente
# eso mismo me sois más querida que la madre que conocí , más querida que todo ,

# %%
#Simililares no significa que sean sinonimos, sino que son palabras que van a encontrarse en un contexto similar o tienen similitud con la palbara de busqueda
texto_nltk.similar("madre")
# Out:
# bruma campana primera bajo muchacha voz cabeza libertad alma
# salutación isla fuerza pecho ciudad piedra impresión angustia
# exactitud naturaleza muerte

# %%
#La función texto_nltk.similar no te devuelve el resultado, sino solo lo imprime
palabras_similares = texto_nltk.similar("madre")
# Out:
# bruma campana primera bajo muchacha voz cabeza libertad alma
# salutación isla fuerza pecho ciudad piedra impresión angustia
# exactitud naturaleza muerte

# %%
print(palabras_similares)
# Out:
# None

# %%
#Utilizamos nltk.text.ContextIndex y idx.similar_words para guardar las palabras similares

import nltk
import nltk.text
import nltk.corpus

#idx = nltk.text.ContextIndex([word.lower( ) for word in tokens])
idx = nltk.text.ContextIndex(tokens)
save = [ ]
for word in nltk.word_tokenize("madre"):
    save.append(idx.similar_words(word))

# %%
save
# Out:
# [['fuerza',
#   'alma',
#   'luz',
#   'campana',
#   'querida',
#   'lecho',
#   'cerebro',
#   'corazón',
#   'pecho',
#   'isla',
#   'voz',
#   'belleza',
#   '_steamer_',
#   'salutación',
#   'memoria',
#   'compañera',
#   'Annie',
#   'alfabeto',
#   'juventud',
#   'espíritu']]

# %%
save = [ ]
for word in nltk.word_tokenize("naturaleza"):
    save.append(nltk.text.ContextIndex(tokens).similar_words(word))
save
# Out:
# [['luz',
#   'isla',
#   'voz',
#   'belleza',
#   'fuerza',
#   'campana',
#   'angustia',
#   'exactitud',
#   'procesión',
#   'maravilla',
#   'venida',
#   'cuna',
#   'influencia',
#   'obra',
#   'publicación',
#   'Irlanda',
#   'empresa',
#   'edición',
#   'observación',
#   'impresión']]

# %%
nltk.text.ContextIndex(tokens).similar_words("Sheldon")
# Out:
# []

# %%
tokens=nltk.word_tokenize(texto,"spanish") 
texto_nltk=nltk.Text(tokens) 
lista_palabras=["las","los","el","ella","ensueño","resplandor","padre"] 
texto_nltk.dispersion_plot(lista_palabras)

# %%
nltk.find(texto,"padre")

# %%
distribucion=nltk.FreqDist(texto_nltk) 
lista_frecuencias=distribucion.most_common() #Para ordenar la distribución de la frecuencia de palabras
print(lista_frecuencias)
# Out:
# [(',', 1078), ('de', 639), ('la', 414), ('y', 367), ('que', 345), ('.', 317), ('en', 299), ('el', 290), ('a', 179), ('un', 153), ('los', 147), ('su', 135), ('!', 131), ('las', 123), ('del', 113), ('--', 108), ('se', 107), ('una', 106), (';', 104), ('mi', 103), ('al', 94), ('por', 87), ('más', 84), ('no', 78), ('con', 73), ('como', 72), ('sobre', 65), ('es', 63), ('sus', 62), (':', 61), ('«', 51), ('tu', 51), ('me', 51), ('»', 49), ('...', 46), ('lo', 44), ('alma', 41), ('todo', 36), ('?', 36), ('para', 35), ('noche', 34), ('ojos', 33), ('Y', 32), ('ha', 31), ('ese', 28), ('era', 28), ('corazón', 27), ('esa', 27), ('jamás', 27), ('tan', 26), ('o', 25), ('ya', 24), ('cual', 24), ('En', 22), ('han', 22), ('amor', 21), ('sin', 21), ('ni', 20), ('siempre', 20), ('nos', 19), ('te', 19), ('le', 19), ('Poe', 19), ('tiempo', 19), ('bajo', 18), ('si', 18), ('él', 18), ('mí', 18), ('dan', 18), ('Pero', 17), ('cuando', 17), ('La', 17), ('donde', 16), ('El', 16), ('estrellas', 16), ('*', 16), ('cada', 16), ('cuervo', 16), ('pero', 16), ('ahora', 16), ('todas', 15), ('nombre', 15), ('esta', 15), ('Dios', 15), ('tus', 15), ('luz', 15), ('A', 14), ('esos', 14), ('porque', 14), ('son', 14), ('cielo', 14), ('espíritu', 14), ('mismo', 14), ('ella', 14), ('frente', 13), ('mar', 13), ('ti', 13), ('mundo', 13), ('entre', 13), ('aquella', 13), ('todos', 13), ('así', 13), ('hasta', 13), ('triste', 13), ('través', 13), ('allá', 13), ('fué', 13), ('fin', 13), ('sino', 13), ('mientras', 13), ('¡Oh', 13), ('entonces', 12), ('otra', 12), ('vida', 12), ('qué', 12), ('sombra', 12), ('dije', 12), ('aquel', 11), ('toda', 11), ('tierra', 11), ('está', 11), ('Por', 11), ('este', 11), ('desde', 11), ('muerte', 11), ('oro', 11), ('hombre', 11), ('nada', 11), ('menos', 11), ('yo', 11), ('tumba', 11), ('cielos', 11), ('fuera', 11), ('voz', 10), ('De', 10), ('parece', 10), ('llama', 10), ('aire', 10), ('alas', 10), ('día', 10), ('mirada', 10), ('poeta', 10), ('palabras', 10), ('tanto', 10), ('sólo', 10), ('esas', 10), ('miradas', 10), ('din', 10), ('tú', 9), ('eres', 9), ('región', 9), ('ser', 9), ('he', 9), ('ángeles', 9), ('hacia', 9), ('mis', 9), ('estaba', 9), ('No', 9), ('Una', 9), ('os', 9), ('esperanza', 9), ('sueño', 9), ('¡Nunca', 9), ('gran', 8), ('tal', 8), ('bien', 8), ('fuerza', 8), ('instante', 8), ('ensueño', 8), ('brillante', 8), ('extraña', 8), ('Eulalia', 8), ('Cielo', 8), ('lago', 8), ('Luna', 8), ('Annabel', 8), ('Lee', 8), ('EL', 8), ('bella', 8), ('misterio', 8), ('aquellos', 8), ('muy', 8), ('edad', 8), ('belleza', 8), ('sea', 8), ('alguna', 8), ('(', 8), (')', 8), ('hora', 8), ('pensamientos', 8), ('ninguna', 8), ('LA', 8), ('puerta', 8), ('has', 8), ('vez', 7), ('largo', 7), ('modo', 7), ('torres', 7), ('recuerdo', 7), ('sér', 7), ('Es', 7), ('rosas', 7), ('calma', 7), ('medio', 7), ('hay', 7), ('puede', 7), ('Los', 7), ('hace', 7), ('¡Qué', 7), ('dos', 7), ('cosas', 7), ('otro', 7), ('reposo', 7), ('dulcemente', 7), ('lecho', 7), ('sombras', 7), ('onda', 7), ('nota', 7), ('suena', 7), ('país', 6), ('mano', 6), ('són', 6), ('tiene', 6), ('¡oh', 6), ('hecho', 6), ('casi', 6), ('pronto', 6), ('ciudad', 6), ('des', 6), ('ola', 6), ('negra', 6), ('ningún', 6), ('Su', 6), ('algún', 6), ('dulce', 6), ('cuya', 6), ('Annie', 6), ('busto', 6), ('forma', 6), ('sido', 6), ('gloria', 6), ('quien', 6), ('podría', 6), ('viejo', 6), ('eso', 6), ('reino', 6), ('luna', 6), ('querida', 6), ('madre', 6), ('muerto', 6), ('oscura', 6), ('seno', 6), ('nunca', 6), ('aguas', 6), ('resplandor', 6), ('haya', 6), ('toque', 6), ('poderío', 6), ('1827', 6), ('bosques', 6), ('Dijo', 6), ('fría', 5), ('primera', 5), ('viento', 5), ('negro', 5), ('ver', 5), ('cabeza', 5), ('bronce', 5), ('Yo', 5), ('soplo', 5), ('cerca', 5), ('pecho', 5), ('uno', 5), ('poesía', 5), ('días', 5), ('hombres', 5), ('allí', 5), ('quiere', 5), ('pasar', 5), ('dice', 5), ('razón', 5), ('imperio', 5), ('drama', 5), ('crece', 5), ('mejor', 5), ('después', 5), ('Leonora', 5), ('velo', 5), ('siento', ...

# %%
lista_palabras=["amor","Dios","mundo","mar"] 
texto_nltk.dispersion_plot(lista_palabras)

# %%
texto_nltk=nltk.Text(tokens) 
distribucion=nltk.FreqDist(texto_nltk) 
print(distribucion["madre"])
# Out:
# 6

# %% [markdown]
# Un hapax es una palabra que aparece únicamente una vez en el texto.

# %%
texto_nltk=nltk.Text(tokens) 
distribucion=nltk.FreqDist(texto_nltk)
hapaxes=distribucion.hapaxes() 
for hapax in hapaxes: 
    print(hapax)
# Out:
# PRÓLOGO
# húmeda
# Iba
# despacio
# sirena
# aullaba
# roncamente
# Quedaba
# Fire
# erecto
# faro
# estábamos
# Sandy
# Hook
# salió
# barco
# sanidad
# ladrante
# slang
# yanqui
# sonaba
# pabellón
# bandas
# pitos
# arromadizados
# humo
# chimeneas
# máquinas
# ventrudas
# estañado
# caminaba
# rumbo
# bahía
# decía
# _all
# right_
# divisaban
# barcos
# Long
# desarrollaba
# cinta
# costas
# Staten
# marco
# viñeta
# presentaba
# tentando
# lápiz
# falta
# fotográfica
# agrupan
# pasajeros
# comerciante
# gruesa
# panza
# congestionado
# pavo
# encorvadas
# narices
# israelitas
# clergyman
# huesoso
# enfundado
# levitón
# cubierto
# sombrero
# fieltro
# Biblia
# usa
# gorra
# jockey
# travesía
# cantado
# fonográfica
# banjo
# robusto
# lampiño
# aficionado
# box
# puños
# desquijarrar
# rinoceronte
# Narrows
# alcanza
# pintoresca
# florida
# fortalezas
# Luego
# gigantesca
# Madona
# peana
# islote
# prolífica
# dominadora
# Nuestra
# Señora
# mamas
# alimentan
# sinnúmero
# alzas
# saludo
# prosternándome
# majestad
# ¡Ave
# Good
# morning
# divino
# icono
# magna
# excelsa
# beldad
# encarnas
# manera
# _fiat_
# listas
# bandera
# iluminan
# formidable
# azules
# Ave
# contigo
# bendita
# ¿sabes
# herido
# divinidad
# manchando
# Anda
# usurpado
# tea
# Aquélla
# sagrada
# incomparables
# flechas
# Hécate.
# Hecha
# masa
# subyugador
# sanguínea
# ciclópea
# monstruosa
# tormentosa
# irresistible
# capital
# cheque
# Rodeada
# menores
# Jersey
# agarrada
# uña
# puente
# ramillete
# oír
# soliloquio
# distinta
# París
# escucharla
# acercarse
# halagadora
# verse
# surgir
# Tío
# Samuel
# pueblos
# inaudito
# remate
# martillo
# rematador
# techumbres
# ensordecedor
# trueno
# Antes
# monstruo
# poema
# bárbaro
# vidente
# Thogorma
# _Thogorma
# dans
# ses
# yeux
# vit
# monter
# murailles
# fer
# dont
# s'enroulaient
# spirales
# tours
# et
# palais
# cerclés
# d'arain
# sur
# blocs
# lourds
# ruche
# énorme
# géhenne
# aux
# entrailles
# oú
# s'engouffraint
# Forts
# princes
# anciens
# jours._
# Semejantes
# Fuertes
# viven
# fabulosa
# Babel
# gritan
# mugen
# resuenan
# braman
# conmueven
# Bolsa
# locomotora
# fragua
# imprenta
# dock
# urna
# electoral
# edificio
# Produce
# Exchange
# granito
# reúne
# cuantas
# pueblo
# experimenta
# dominio
# vértigo
# canal
# lados
# casas
# monumentales
# ostentan
# cien
# vidrio
# tatuajes
# rótulos
# caudaloso
# confuso
# comerciantes
# corredores
# caballos
# tranvías
# ómnibus
# hombres-sandwichs
# vestidos
# anuncios
# mujeres
# bellísimas
# Abarcando
# arteria
# hervor
# continuo
# sentirse
# ciertas
# pesadillas
# Reina
# percherones
# carros
# monstruosos
# clase
# vehículos
# vendedor
# periódicos
# rosado
# risueño
# salta
# gorrión
# grita
# pasajero
# _¡intanrsooonwoood
# _
# decir
# gustáis
# cualquiera
# tres
# diarios
# _Evening
# Telegram_
# _el
# Sun_
# _World_
# mareador
# trepidación
# incesante
# repiqueteo
# cascos
# ruedas
# aumentarse
# Temeríase
# fracaso
# conociese
# alud
# exactitud
# intrincado
# convulsivo
# crespo
# sucede
# lady
# anciana
# capota
# miss
# rubia
# nodriza
# acera
# corpulento
# policeman
# alza
# detiénese
# torrente
# ¡all
# right
# cíclopes
# Groussac
# feroces
# calibanes
# escribe
# Peladan
# ¿Tuvo
# Sar
# Norte
# San
# Francisco
# conseguido
# establecer
# misterioso
# Edison
# apoteosis
# puerco
# abrumadora
# Chicago
# satura
# wishky
# Shakespeare
# desarrolla
# esclavo
# Próspero
# martirizado
# engorda
# multiplica
# Legión
# suele
# monstruos
# Miranda
# mueve
# Sicorax
# destierra
# mata
# mía
# presto
# ida
# recorrer
# hirviente
# harmonioso
# vaga
# desfilar
# procesión
# enamoradas
# liliales
# vírgenes
# cantadas
# brumosa
# infeliz
# malditos
# Tú
# Frente
# balcón
# Paraíso
# asoma
# generosos
# profundos
# hermanas
# saludan
# virtud
# consolador
# marea
# segunda
# violeta
# dirige
# tercera
# radiosa
# distante
# Francés
# penas
# yerra
# Helen
# ósculos
# caricias
# oraciones
# adorado
# amó
# envidia
# Isabel
# amantes
# coloquios
# meditabunda
# envuelta
# extraterrestre
# Ellas
# cándido
# oceánidos
# consuelan
# enjugan
# Prometeo
# amarrado
# Yankee
# esquiliano
# sentado
# apuñaleándole
# monótona
# desesperanza
# martirios
# refrescas
# alientas
# partiste
# retorno
# inmortal
# faltan
# arco
# Alma
# oigo
# sonar
# escudo
# angélico
# surge
# incomparable
# guía
# inefable
# llevo
# incienso
# mirra
# cuna
# Esperanza
# HOMBRE
# suficientemente
# transcendente
# continua
# recordados
# año
# revista
# ocupen
# excelso
# críticos
# ensayistas
# iluminó
# aumentar
# publicación
# agradecer
# destinada
# grueso
# público
# ¿Es
# número
# escogidos
# aristócratas
# pesado
# fárrago
# canino
# Griswold
# infame
# autopsia
# hizo
# tener
# protesta
# libre
# mancha
# inmaculado
# Ariel
# diríase
# flotante
# influjo
# Nacido
# práctica
# contrario
# cálculo
# estupenda
# mitológico
# atavismo
# vese
# azul
# nacieron
# antepasados
# Renace
# caballeresca
# alabados
# crónicas
# Generaldo
# Gambresio
# Irlanda
# 1327
# insulto
# Mauricio
# Desmond
# Sois
# rimador.
# empuñan
# espadas
# traba
# riña
# prólogo
# guerra
# sangrienta
# Cinco
# descendiente
# provocativo
# glorificará
# raza
# erigiendo
# rico
# pedestal
# palacio
# rimas
# abolengo
# interesa
# gusto
# producidos
# peculiaridades
# mentales
# constitucionales
# Sra
# Whitman
# demás
# valer
# honra
# pastores
# protestantes
# tenderos
# rentistas
# mercachifles
# llevan
# apellido
# honorable
# padre
# patria
# Jorge
# bravo
# Rogerio
# batalló
# compañía
# Strongbow
# osado
# defendió
# _lady_
# acusada
# bruja
# heroica
# célebre
# _Condesa_
# Cromwell
# enredos
# genealógicos
# General
# abuelo
# Después
# trágico
# historia
# romancesca
# vagido
# coronas
# marchitas
# comedianta
# quedado
# huérfana
# tierna
# Amaba
# gracia
# envidiable
# corporal
# suyos
# ninguno
# idea
# especial
# descripciones
# muchas
# conocieron
# iconografía
# poeana
# debe
# representarle
# sirvió
# publicar
# copiaba
# trabajaba
# empresa
# protestó
# falsos
# publicaron
# calumniaron
# hermosa
# poética
# desfiguran
# dignos
# censura
# manos
# llamado
# atención
# publicado
# ilustrada
# Quantin
# _Cuentos
# extraordinarios_
# R.
# Loncup
# madura
# gallardo
# jovencito
# sensitivo
# Stannard
# Dante
# _Vita
# Nuova_
# sufrido
# conoce
# propias
# desgarradas
# carnes
# hieren
# asperezas
# primero
# hacer
# ornitomorfos
# trágica
# intentado
# pintar
# autor
# _Cuervo_
# _unhappy
# Master_
# segundo
# realidad
# contagiosa
# apretada
# entronizó
# pintan
# desgraciado
# infortunio
# precedieron
# Halpin
# Amstrong
# tipos
# lechuguinos
# época
# caras
# Clark
# Nada
# observación
# Gautier
# reputación
# fatigas
# estudio
# lucha
# torturas
# pasiones
# alterado
# primitiva
# máscara
# usada
# marchita
# puesto
# estigma
# magulladura
# arruga.
# prometía
# belleza.
# Sus
# colegio
# agilidad
# robustez
# temperamento
# estaban
# contrapesados
# músculos
# delicado
# sabía
# excelentes
# puñetazos
# dirá
# bonito.
# West
# Point
# notar
# colega
# Gibson
# cansada
# tediosa
# hastiada.
# recuérdale
# bibliófilo
# Gowans
# exterior
# notablemente
# agradable
# predisponía
# favor
# llamarían
# claramente
# bello.
# oye
# recitar
# realización
# manera.
# precioso
# femenina
# talla
# altura
# mediana
# perfectamente
# proporcionada
# llevada
# regiamente
# juicio
# causaba
# estatura
# dominante
# claros
# melancólicos
# parecían
# eran
# rasgo
# impresionaba
# atractivo
# peculiar
# Jamás
# parecieran
# Eran
# grandes
# pestañas
# iris
# poseía
# transparencia
# expandirse
# contraerse
# Observé
# párpados
# contraían
# usual
# principalmente
# encogimiento
# habitual
# soñadora
# algunas
# dirigir
# ligera
# soslayo
# observaba
# fija
# mentalmente
# midiendo
# calibre
# ajena
# ello.
# tremendos
# señor
# helar
# verle
# darse
# fijarlos
# hablando
# Usaba
# bigote
# esmeradamente
# cuidado
# ligeramente
# contraída
# tensión
# ocasional
# asemejaba
# Esta
# fácilmente
# excitada
# manifestaba
# perceptible
# intensamente
# expresivo
# malevolencia
# sarcasmo
# potente
# encerrada
# vaso
# Parece
# distinción
# dotes
# físicas
# deberían
# nativas
# portadores
# lira
# ¿Apolo
# crinado
# numen
# prototipo
# nacen
# dote
# espléndido
# privilegiados
# Goethe
# Lamartine
# Nuestro
# organización
# vigorosa
# cultivada
# resistir
# dolencia
# médico
# escritor
# propiedad
# sublime
# apasionado
# divinos
# semilocos
# necesarios
# progreso
# lamentables
# cristos
# calle
# amargura
# espinas
# cruz
# Nació
# adorable
# alimentaba
# martirio
# huérfano
# adoptivo
# pasará
# porvenir
# imaginarse
# recitador
# alegraba
# veladas
# _home_
# egregio
# Arte
# niñez
# protector
# Londres
# dómine
# Brondeby
# despierta
# extrañas
# reminiscencias
# morada
# profesor
# hacerle
# subyugadoras
# páginas
# posee
# facultad
# matemática
# poblado
# quimeras
# carta
# astrólogo
# Vuelto
# vémosle
# Richmond
# nutre
# clásicos
# recita
# odas
# latinas
# boxea
# _champion_
# estudiantil
# carrera
# Atalanta
# aspiraba
# lauros
# natatorios
# descuella
# físicamente
# fofa
# aristocracia
# hombro
# cómica
# ¿Cuánta
# hiel
# tuvo
# devorar
# exquisito
# humillado
# origen
# posteriores
# habría
# orgullosamente
# gloriarse
# primeros
# golpes
# empezaron
# cincelar
# pliegue
# amargo
# sarcástico
# temprano
# asechanzas
# lobo
# racional
# buscaba
# comunicación
# sana
# fortalecedora
# Odio
# detesto
# animal
# escribía
# Swift
# mezquina
# amistad
# fidelidad
# polvillo
# fruta
# gossamer
# fidelity
# mero
# Job
# _Eliphaz
# Themanita_
# exclama
# ¿Cuánto
# abominable
# vil
# inquietud
# buscó
# apoyo
# oración
# creyente
# alejada
# misticismo
# James
# Russell
# Lowell
# llamarse
# matematicidad
# cerebración
# Hasta
# matemático
# impide
# penetrar
# tender
# verdades
# necesidad
# análisis
# condición
# algebraica
# hácele
# tristísimos
# arrastra
# desconocido
# especulación
# nubló
# debiera
# poseer
# verdadero
# obras
# unas
# escrito
# Cristo
# Profesaba
# cristiana
# cuanto
# ley
# fallo
# inexorable
# ecuación
# dominaba
# creencia
# referente
# tributos
# pensaba
# Spinosa
# invisibles
# objeto
# entendimiento
# percibirse
# demostración
# afirmación
# _Intelectus
# noster
# sic
# ¿de
# habet
# prima
# entium
# quæ
# sunt
# manifestissima
# in
# natura
# sicut
# oculus
# vespertillionis
# solem._
# sobrenatural
# confesión
# afirmaba
# Creador
# modificarla
# narración
# metempsícosis
# definición
# tomada
# Granwill
# sustentada
# intensidad
# Lo
# Santo
# Tomás
# estas
# determinan
# desconocen
# determine
# determinador
# previene
# llamamos
# _Revelación
# Magnética_
# divagaciones
# filosóficas
# Vankirk
# personajes
# afirma
# comprensión
# diálogo
# Oinos
# Agathos
# pretende
# sondear
# inteligencia
# Monos
# Eros
# Charmion
# desconocida
# pocos
# vislumbres
# concepción
# espacio
# _Rubén
# Darío._
# POEMAS
# TRADUCCIÓN
# ALBERTO
# LASPLACES
# ANNABEL
# LEE
# Hace
# bastantes
# podéis
# amarme
# _ella_
# amábamos
# poderoso
# heló
# padres
# vinieron
# llevaron
# encerrarla
# sentían
# mitad
# éramos
# sabe
# helando
# aventajan
# demonios
# abismos
# podrán
# separar
# traerme
# creo
# brillar
# acostada
# quejumbrosa
# MI
# MADRE
# arriba
# radiantes
# ferviente
# _madre_
# llamo
# llenáis
# instalado
# libertar
# Virginia
# murió
# fuisteis
# quise
# tiernamente
# sois
# conocí
# PARA
# ANNIE
# ¡Gracias
# crisis
# lánguida
# vencida
# Tristemente
# desposeído
# muevo
# músculo
# Siento
# voy
# paulatinamente
# contemplarme
# estremecer
# viera
# apaciguadas
# ¡ah
# incomodidad
# disgusto
# enloquecía
# consumía
# tormentos
# tormento
# pasión
# maldita
# arrullador
# subterránea
# caverna
# cuarto
# estrecho
# durmió
# igual
# _dormir_
# verdaderamente
# acostarse
# tantalizada
# recordarlas
# antiguas
# ansias
# mirtos
# Pues
# imagina
# mezclado
# sabor
# callejero
# rígidos
# dichosamente
# sumergida
# anegada
# trenzas
# Tiernamente
# abraza
# apasionadamente
# acaricia
# caigo
# adormido
# conociendo
# serenamente
# estremecéis
# verme
# abrasado
# luminosos
# ELDORADO
# Brillantemente
# ataviado
# galante
# viajó
# cantando
# animoso
# encontró
# faltaron
# peregrina.
# Sombra
# preguntó
# ¿dónde
# estar
# descanso
# respondió
# buscáis
# EULALIA
# Vivía
# estancada
# pudorosa
# sonriente
# brillan
# girón
# emergido
# irisado
# modesta
# humilde
# pena
# invaden
# entrega
# eleva
# Recibid
# dejo
# permitidme
# confesar
# agraviéis
# estimáis
# Entretanto
# ¿se
# bramidos
# costa
# atormentada
# resaca
# granos
# arena
# deslizan
# dedos
# abismo
# puedo
# retenerlos
# nudo
# podré
# salvar
# ¿Todo
# CIUDAD
# MAR
# occidente
# buenos
# peores
# mejores
# carcomidas
# tiemblan
# parecen
# nuestras
# olvidadas
# sagrado
# reflejado
# lívida
# invade
# almenas
# hondo
# reales
# murallas
# babilónicas
# macizos
# esculpida
# flores
# templo
# contorneados
# entrelazan
# claveles
# viñas
# confunden
# suspendido
# gigante
# pies
# abiertos
# tumbas
# bostezan
# nivel
# luminosas
# riquezas
# muestran
# adiamantados
# ídolo
# cadáveres
# rientes
# adornos
# quitan
# ondulación
# arruga
# desierto
# indica
# puedan
# existir
# suponer
# horrorosamente
# serenos
# estremecimiento
# diría
# bamboleado
# hubieran
# ligero
# brumoso
# transcurren
# sordas
# lánguidas
# tengan
# terrestres
# engullida
# fijada
# levantándose
# Infierno
# rendirá
# homenaje
# DURMIENTE
# Junio
# opio
# exhala
# halo
# filtrando
# cumbre
# resbala
# perezosa
# armoniosamente
# adormece
# lis
# inclina
# Envolviéndose
# hunde
# Ved
# Leteo
# adormecerse
# sabiendas
# Toda
# princesa
# dejar
# juguetones
# filtran
# incorpóreos
# magos
# revolotean
# flotar
# cortinas
# dosel
# fantásticamente
# tímidamente
# párpado
# franjeado
# piso
# muro
# descienden
# ronda
# Querida
# tienes
# sueñas
# Has
# jardín
# Extraña
# longitud
# ¡Ella
# durable
# ¡que
# tenga
# guardia
# transformada
# melancólica
# rogaré
# deje
# dormir
# cerrados
# errarán
# ¡ella
# gusanos
# deslicen
# abrirse
# panneaux
# triunfantes
# estandartes
# bordados
# armas
# aislada
# portada
# infancia
# lanzado
# ociosas
# sonora
# devuelva
# nuevos
# estremecía
# fueran
# respondiesen
# gimiendo
# BALADA
# NUPCIAL
# anillo
# dedo
# poseo
# rasos
# abundancia
# ama
# pronunció
# voto
# sentí
# estremecerse
# sonaron
# agonía
# batalla
# dichoso
# habló
# tranquilizarme
# besó
# delirio
# transportó
# cementerio
# pensando
# Elormie
# suspiré
# fueron
# pronunciadas
# empeñado
# juramento
# apagado
# llegue
# quebrarse
# prenda
# prueba
# ¡Quiera
# dolorosamente
# llegar
# abandonado
# COLISEO
# ¡Símbolo
# antigua
# ¡Suntuoso
# relicario
# contemplaciones
# legadas
# difuntos
# pompa
# tantos
# fatigante
# peregrinaje
# corrientes
# ciencia
# transformado
# arrodillo
# humildemente
# bebo
# ¡Inmensidad
# Silencio
# Os
# percibo
# vuestra
# sortilegios
# eficaces
# rey
# Judea
# enseñó
# jardines
# Gethsemaní
# encantos
# Caldea
# arrancó
# tranquilas
# columna
# teatral
# murciélago
# aquelarre
# romanas
# flotaba
# balancean
# cardo
# caña
# monarca
# silencioso
# lagarto
# desliza
# mármol
# creciente
# oíd
# arcadas
# revestidas
# zócalos
# musgosos
# columnas
# ennegrecidas
# relieves
# ruinosos
# cornisas
# rotas
# naufragio
# grises
# famoso
# corrosivas
# perdonado
# Destino
# responden
# Voces
# fuertes
# proféticas
# intención
# sabios
# parecidas
# himnos
# Memnon
# Sol
# Reinamos
# reinamos
# despótico
# gigantes
# somos
# impotentes
# nosotras
# prestigio
# renombre
# circunda
# moran
# prenden
# nuestros
# flancos
# envolviéndonos
# 1833
# GUSANO
# VENCEDOR
# gala
# solitarios
# multitud
# alados
# adornados
# anegados
# halla
# reunida
# temores
# orquesta
# suspira
# intervalos
# música
# esferas
# Actores
# creados
# Altísimo
# murmuran
# saltan
# fantoches
# van
# vienen
# órdenes
# vastas
# creaturas
# informes
# cambian
# decoración
# capricho
# sacudiendo
# cóndor
# abigarrado
# estad
# olvidado
# perseguido
# atraparlo
# círculo
# gira
# intriga
# mucha
# bulla
# rampante
# entrada
# color
# sanguinolento
# retorciéndose
# escena
# retuerce
# Con
# angustias
# constituyen
# sollozan
# viendo
# mandibulas
# teñirse
# Todas
# apagan
# tiritante
# telón
# paño
# mortuorio
# pálidos
# macilentos
# cubriéndose
# afirman
# tragedia
# Gusano
# Vencedor
# 1838
# ELENA
# barcas
# niceanas
# llevaban
# cansado
# natal
# Largo
# habituado
# errar
# desesperados
# jacinto
# clásico
# perfil
# cantos
# transportado
# Grecia
# espléndida
# abertura
# parecida
# lámpara
# ágata
# regiones
# Tierra
# Bendita
# CIENCIA
# verdadera
# indiscreta
# transforma
# haces
# sombrías
# realidades
# ¿Cómo
# amarte
# sabia
# dejarlo
# vagar
# tesoros
# constelados
# subiera
# intrépida
# arrancado
# carro
# obligado
# hamadriadas
# buscar
# sacado
# elfo
# pradera
# verde
# arrebatado
# estival
# tamarindos
# odio
# desolados
# dichosos
# afligís
# transeúnte
# umbrías
# traviesos
# pájaros
# cantores
# creadas
# engastados
# desoladas
# ¡Tu
# vuelvo
# dormirme
# ensoñar
# capaz
# locuras
# AL
# RÍO
# ¡Bello
# clara
# vagabunda
# Alberto
# mira
# ríos
# adoradores
# grabada
# CANCIÓN
# invadía
# Amor
# vivificante
# encontré
# Ese
# virginal
# impetuosa
# ¡pobre
# rubor
# estuvieras
# ESPÍRITUS
# MUERTOS
# encontrará
# cautiva
# tumbal
# inquietará
# recogimiento
# Quédate
# abandono
# existieron
# alcanzarán
# rodearán
# proyectada
# obedecerá
# permanece
# fruncirá
# ceño
# celestes
# bajarán
# concede
# desprovistas
# serán
# quemadura
# querrá
# unirse
# Ahora
# visitan
# ahuyentarás
# surgen
# desvanecerán
# dejarán
# fijarán
# gotas
# hierba
# brisa
# respiración
# colina
# desgarrado
# resulta
# símbolo
# signo
# logra
# permanecer
# suspendida
# ROMANZA
# romanza
# gustas
# cantar
# plegadas
# verdes
# agitadas
# umbrío
# papagayo
# vivos
# colores
# familiar
# enseñado
# alfabeto
# balbucear
# primeras
# sagaz
# hundía
# huraños
# Cóndor
# estremecido
# agrandando
# tumulto
# pasaje
# huida
# obstinadamente
# inquietante
# ocios
# REINO
# HADAS
# torrentes
# umbríos
# nebulosos
# descubrir
# formas
# causa
# lloran
# lunas
# desmesuradas
# crecen
# decrecen
# cambiando
# hálito
# faces
# temblorosas
# Hacia
# duodécima
# cuadrante
# especie
# probado
# pone
# centro
# vasta
# circunferencia
# esparce
# vestiduras
# flotantes
# caseríos
# mansiones
# distantes
# danzan
# sepulta
# laberinto
# ¡cuán
# éxtasis
# vuela
# albatros
# sacude
# refugiado
# servido
# decirlo
# tienda
# volver
# abrigo
# átomos
# dispersan
# convierten
# lluvia
# mariposas
# vuelven
# ¡criaturas
# satisfechas
# devuelven
# partículas
# estremecidas
# LAGO
# primavera
# frecuentar
# salvaje
# rodeado
# peñascos
# pinos
# dominaban
# alrededores
# tendía
# agregaba
# murmurando
# despertaba
# turbación
# deliciosa
# sentimiento
# mina
# preciosas
# inspirarme
# convidarme
# definir
# reinaba
# envenenada
# remolino
# beber
# desamparada
# haberse
# velado
# ESTRELLA
# TARDE
# verano
# marchando
# brillaban
# ésta
# planetas
# esclavos
# lanzaba
# olas
# contemplaba
# volví
# Estrella
# Sur
# traes
# magnificente
# prefiero
# discreto
# cercana
# DÍA
# MÁS
# FELIZ
# agotado
# alta
# ¿He
# Sí
# desvanecido
# dejémoslos
# desvanezcan
# haré
# heredar
# veneno
# dado
# permanezca
# podido
# existe
# ofrecida
# acompañada
# experimento
# revivir
# llevaba
# mezcla
# volaba
# dejaba
# caer
# todopoderosa
# consumir
# conocía
# IMITACIÓN
# insondable
# debió
# parecer
# añado
# atravesado
# apercibido
# ensoñadora
# herede
# extienden
# hechizo
# liviano
# preocupo
# perezca
# TRADUCIDOS
# CARLOS
# ARTURO
# TORRES
# CAMPANAS
# dilata
# campanilleo
# trineo
# expresa
# ambiente
# glacial
# Mientras
# astrales
# titilan
# cristales
# hielos
# sube
# dilatando
# confín
# campanilla
# ¡Melodiosa
# argentina
# límpido
# ¡Escuchad
# puebla
# boda
# venturanza
# plácida
# caricia
# suave
# reproche
# desgrana
# perlas
# delicia
# áureas
# notas
# ledo
# murmullo
# enamorado
# arrullo
# tórtola
# dormida
# laguna
# vierte
# linfas
# palpita
# serenata
# áurea
# balsámico
# efluvio
# primaveral
# celebrando
# ¡Turba
# sosiego
# súbita
# alarma
# terrífica
# siniestra
# augura
# desesperado
# ruego
# desgarrador
# tenaz
# elemento
# ciego
# frenético
# voraz
# indescriptible
# pánico
# cataclismo
# raudo
# titánico
# campanada
# alarido
# clamoroso
# estruendo
# diciendo
# peligro
# horrendo
# inflama
# sangriento
# tabernáculo
# alumbra
# espectáculo
# alarmante
# injuria
# incendio
# furia
# pavor
# escarlatas
# inflamado
# espanto
# armígero
# estrago
# flamígero
# violento
# tocando
# Dobla
# invita
# entierro
# solemnes
# despiertan
# acentos
# Del
# gemido
# estremecida
# admonición
# ¡Se
# desprenden
# vibración
# alienta
# irónico
# zumba
# agrio
# sardónico
# derrumba
# oprime
# peso
# ¡Quienes
# tañen
# toques
# funerales
# campaneros
# sencillos
# sepulcrales
# tesón
# Pausado
# lamento
# pregonando
# sintiera
# placer
# diabólico
# Din
# monótono
# gozo
# refina
# sollozo
# giro
# remeda
# doble
# augural
# recordando
# final
# cesa
# vibra
# opresa
# sordamente
# cuerpo
# cayera
# huesa
# ¡Din
# ULALUME
# cenicientos
# sombríos
# crespas
# lívidas
# márgenes
# tenebroso
# tétricos
# solas
# recorría
# titánica
# cipreses
# llamas
# sulfúreas
# lavas
# brotan
# polo
# nocturna
# Pocas
# dijimos
# confidencia
# íntima
# muda
# serias
# graves
# turban
# ¡noche
# tremer
# lánguido
# fulgor
# diamantino
# anuncia
# emerge
# fantástica
# misteriosa
# mostrarnos
# ruta
# Letea
# traspasando
# despecho
# ora
# límpidas
# anuncian.
# VI
# señalando
# conturba
# huyamos
# preciso.
# plegó
# lentas
# dejando
# VII
# trémula
# bañen
# cristalinos
# sibilinos
# auguran
# irradian
# Mira
# limpios
# llevarán
# segura
# limpia
# bóveda
# cerúlea
# VIII
# Tranquilicé
# besándola
# mente
# aparté
# inquietudes
# zozobras
# disipé
# profundas
# convencerla
# siguiera
# pude
# Llegamos
# ¡ojalá
# llegara
# monumento
# inscripción
# confusa
# sellada
# descubre
# Respondiome
# ¡la
# IX
# Quedó
# ceniciento
# yertas
# crispadas
# ¡Ay
# pensé
# _esa
# noche_
# vine
# trayendo
# carga
# infernal
# trajo
# tristura
# reconozco
# comarca
# anubla
# ESTRELLAS
# FIJAS
# TO
# HELEN
# julio
# tibia
# perfumada
# plena
# descendían
# gráciles
# ráfaga
# quietud
# perturbaban
# evaporaban
# perfumes
# recogieras
# mágica
# aspiraras
# aliento
# claridades
# ¡Toda
# blanco
# vestida
# reclinada
# moribundas
# tenue
# alumbraba
# diluida
# evaporadas
# hado
# ¿fué
# ventura
# condujo
# perfumados
# Ni
# hoja
# susurraba
# pisada
# ¡cuál
# agito
# unir
# cambia
# perfume
# dormidas
# auras
# senderos
# expiran
# violas
# huye
# ¡Todo
# extingue
# arde
# tristezas
# extrahumanas
# irreales
# leyendas
# relatan
# dolores
# renunciaciones
# expresan
# fijan
# ¡Noche
# turbios
# nubarrones
# hundió
# plateada
# funeraria
# alejas
# incorpórea
# flotan
# quedan
# espacios
# sendero
# ¡Van
# cándidas
# apareadas
# purifican
# abrasan
# prosterno
# adoración
# ocultan
# ocultó
# siguen
# mirándome
# fijamente
# clavadas
# ¡Misteriosas
# lejanas
# persiguen
# DREAMLAND
# crucé
# atrevido
# Reino
# entré
# confines
# lindes
# riberas
# densos
# titánicos
# desafían
# base
# mudos
# bordes
# escarpados
# gélidos
# muertas
# copian
# tétrico
# Orillas
# reflejan
# fatídico
# enfrente
# océanos
# montes
# formidables
# hondos
# antros
# vense
# silenciosos
# dolientes
# ¡son
# dejaron
# caros
# idos
# nutrida
# acaso
# azorado
# cruza
# espantos
# perennemente
# seguirán
# sellados
# incontrastado
# desolada
# Diosa
# inexplorada
# última
# esfuma
# abrumada
# ¡He
# pos
# huyeron
# CUERVO
# TRADUCIDO
# J.
# PÉREL
# BONALDO
# fosca
# reflexiones
# infolio
# cronicones
# soñoliento
# alguien
# suavemente
# pusiese
# incierta
# visita
# llamando
# crudo
# hielo
# brasa
# moribunda
# enviaba
# Cuán
# ansioso
# deseaba
# lectura
# par
# querubes
# crujido
# incierto
# colgaduras
# aterraba
# llenaba
# pavuras
# latido
# instancia
# tardío
# Paso
# bríos
# cobrando
# Caballero
# perdones
# demando
# dormía
# vinisteis
# delicadeza
# pusisteis
# ¡sombras
# Mudo
# haciendo
# empeños
# soñó
# forjando
# acusaba
# alguno
# Resonar
# escuchaba
# murmurar
# ¡Leonora
# ¡nada
# retornando
# turbulencia
# violencia
# posa
# veamos
# llana
# serio
# enigma
# ¡Corazón
# Calma
# aclaremos
# rítmico
# aleteo
# garbo
# entró
# majestuoso
# sacra
# antaño
# Sin
# pararse
# señales
# susto
# señorial
# posarse
# Minerva
# cabezal
# figura
# representa
# posose
# Trocó
# sonrisas
# torva
# seria
# decorosa
# cresta
# calva
# llevas
# nocturnal
# vagabundo
# tiniebla
# Dime
# ¿Cuál
# plutoniano
# niebla
# Asombrado
# oyendo
# hablar
# avechucho
# árida
# expresaba
# preciso
# convengamos
# criatura
# lograse
# encaramada
# bruto
# reposar
# cincelada
# vinculada
# sacudía
# acento
# pronunciar
# Dije
# marchado
# aurora
# despuntar
# irá
# volando
# volado.
# abrupta
# sorprendido
# amo
# desdichoso
# duelo
# canciones
# terminar
# ritornelo
# provocando
# sillón
# rodé
# luego
# hundiéndome
# seda
# juntar
# pretendía
# ominoso
# hosco
# torvo
# graznar
# Quedé
# aquesto
# investigando
# encendidos
# abrasaban
# cojines
# reclinado
# anhelo
# empeñaba
# descifrar
# do
# imprimía
# huella
# fanal
# púrpura
# volverá
# oprimir
# Pareciome
# incógnito
# incensario
# querube
# columpiase
# perfumado
# Miserable
# angelical
# olvido
# brindar
# ¡bebe
# nepente
# olvida
# Eh
# duende
# seas
# envíe
# tormenta
# veas
# ábregos
# barrido
# desolado
# intrépido
# hogar
# males
# devastado
# imploro
# ¿Llegaré
# bálsamo
# Oh
# combo
# zafir
# cobija
# adoramos
# dile
# adolorida
# doncella
# arrobadora
# estrechar
# arcángeles
# señal
# partida
# grité
# alzándome
# ¡Retorna
# hórrida
# guarida
# plutónica
# horrenda
# falsedad
# dejes
# ¡El
# ¡Deja
# Quita
# pico
# umbral
# aleja
# escultura
# demonio
# durmiendo
# cayendo
# arroja
# trunca
# alzará
# FIN

# %%
len(hapaxes)
# Out:
# 2499

# %%
#STOPWORDS
nltk.download() #Para descargar paquetes
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml

# %%
import nltk
palabras_funcionales=nltk.corpus.stopwords.words("spanish")
for palabras_funcional in palabras_funcionales: 
    print(palabras_funcional)

# %%
tokens=nltk.word_tokenize(texto,"spanish")
tokens_limpios=[] 
tokens = [token.lower( ) for token in tokens]
for token in tokens: 
    if token not in palabras_funcionales: 
        tokens_limpios.append(token)
print(len(tokens)) 
print(len(tokens_limpios))
# Out:
# 13940
# 8306

# %%
nltk.FreqDist(nltk.Text(tokens_limpios)).plot(20)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
tokens_limpios=[] 
for token in tokens: 
    if token not in palabras_funcionales: 
        if len(token) > 2: 
            tokens_limpios.append(token)
print(len(tokens_limpios))
# Out:
# 6258

# %%
nltk.FreqDist(nltk.Text(tokens_limpios)).plot(20)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# # Stemming
#
# Reducir palabras a su raíz (puede no tener significado):
#  + Organise, organising, organisation --> organis
#  + intelligence, intelligently --> intelligen

# %% [markdown]
# Para hacer stemming usamos el algoritmo *Porter stemmer*
# https://tartarus.org/martin/PorterStemmer/

# %%
from nltk.stem import PorterStemmer

# %%
texto = "hi dear students, how are you doing? we are almost finishing the bootcamp. we hope you are learning and enjoying the course."
texto
# Out:
# 'hi dear students, how are you doing? we are almost finishing the bootcamp. we hope you are learning and enjoying the course.'

# %%
nltk.word_tokenize(texto,"english")
# Out:
# ['hi',
#  'dear',
#  'students',
#  ',',
#  'how',
#  'are',
#  'you',
#  'doing',
#  '?',
#  'we',
#  'are',
#  'almost',
#  'finishing',
#  'the',
#  'bootcamp',
#  '.',
#  'we',
#  'hope',
#  'you',
#  'are',
#  'learning',
#  'and',
#  'enjoying',
#  'the',
#  'course',
#  '.']

# %%
from nltk.tokenize import sent_tokenize
frases = sent_tokenize(texto) #Crea tokens de frases 
frases
# Out:
# ['hi dear students, how are you doing?',
#  'we are almost finishing the bootcamp.',
#  'we hope you are learning and enjoying the course.']

# %%
stemmer = PorterStemmer()
nueva_frase = []

for i in range(len(frases)):
    words = nltk.word_tokenize(frases[i])
    words=[stemmer.stem(word) for word in words]
    nueva_frase.append(' '.join(words))
    
' '.join(nueva_frase)
# Out:
# 'hi dear student , how are you do ? we are almost finish the bootcamp . we hope you are learn and enjoy the cours .'

# %%
texto
# Out:
# 'hi dear students, how are you doing? we are almost finishing the bootcamp. we hope you are learning and enjoying the course.'

# %% [markdown]
# ## Lematización
# Similar al stemming, pero ahora la raíz sí que tiene significado:
# + going, goes, gone --> go
# + intelligence, intelligently --> intelligent

# %%
from nltk.stem import WordNetLemmatizer

# %%
frases = sent_tokenize(texto)
lemmatizer = WordNetLemmatizer()
nueva_frase = []

for i in range(len(frases)):
    words = nltk.word_tokenize(frases[i])
    words=[lemmatizer.lemmatize(word) for word in words]
    nueva_frase.append(' '.join(words))
    
nueva_frase
# Out:
# ['hi dear student , how are you doing ?',
#  'we are almost finishing the bootcamp .',
#  'we hope you are learning and enjoying the course .']

# %%
texto
# Out:
# 'hi dear students, how are you doing? we are almost finishing the bootcamp. we hope you are learning and enjoying the course.'

# %%
texto2 = 'john is an intelligent individual. he intelligently does smart work. he is a top performer in the intelligence'
texto2
# Out:
# 'john is an intelligent individual. he intelligently does smart work. he is a top performer in the intelligence'

# %%
frases = sent_tokenize(texto2)
lemmatizer = WordNetLemmatizer()
nueva_frase = []

for i in range(len(frases)):
    words = nltk.word_tokenize(frases[i])
    words=[lemmatizer.lemmatize(word) for word in words]
    nueva_frase.append(' '.join(words))
    
nueva_frase
# Out:
# ['john is an intelligent individual .',
#  'he intelligently doe smart work .',
#  'he is a top performer in the intelligence']

# %%
words=[lemmatizer.lemmatize(word) for word in nltk.word_tokenize(texto2)]
words
# Out:
# ['john',
#  'is',
#  'an',
#  'intelligent',
#  'individual',
#  '.',
#  'he',
#  'intelligently',
#  'doe',
#  'smart',
#  'work',
#  '.',
#  'he',
#  'is',
#  'a',
#  'top',
#  'performer',
#  'in',
#  'the',
#  'intelligence']

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sia = SentimentIntensityAnalyzer()

# %%
texto= '''
The National Guard has been released in Minneapolis to do the job that the Democrat Mayor couldn’t do. Should have been used 2 days ago & there would not have been damage & Police Headquarters would not have been taken over & ruined. Great job by the National Guard. No games!
'''
tokens=nltk.word_tokenize(texto)

# %%
for token in tokens:
    ss = sia.polarity_scores(token)
    print(token)
    print(ss)
# Out:
# The
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# National
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Guard
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# has
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# been
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# released
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# in
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Minneapolis
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# to
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# do
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# the
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# job
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# that
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# the
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Democrat
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Mayor
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# couldn
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ’
# {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
# t
# {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
# do
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# .
# {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
# Should
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# have
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# been
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# used
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 2
# {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
# days
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ago
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# &
# {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
# there
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# would
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# not
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# have
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# been
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# damage
# {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.4939}
# &
# {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
# Police
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Headquarters
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# would
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# not
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# have
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# been
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# taken
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# over
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# &
# {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
# ruined
# {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.4767}
# .
# {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
# Great
# {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.6249}
# job
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# by
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# the
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# National
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Guard
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# .
# {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
# No
# {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.296}
# games
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# !
# {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}

# %%
def sentiment_scores(frase):
    score = sia.polarity_scores(frase)
    print("{:-<40} {}".format(frase, str(score)))

# %%
sentiment_scores(texto)
# Out:
# The National Guard has been released in Minneapolis to do the job that the Democrat Mayor couldn’t do. Should have been used 2 days ago & there would not have been damage & Police Headquarters would not have been taken over & ruined. Great job by the National Guard. No games!
#  {'neg': 0.096, 'neu': 0.777, 'pos': 0.127, 'compound': 0.4059}

# %%
sentiment_scores("devil")
# Out:
# devil----------------------------------- {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound': -0.6597}

# %%
# Traducción con google Translate

# %%
from googletrans import Translator
translator = Translator()

# %%
traduccion = translator.translate('The National Guard has been released in Minneapolis to do the job that the Democrat Mayor couldn’t do.',dest='es')
traduccion.text
# Out:
# 'La Guardia Nacional ha sido puesto en libertad en Minneapolis para hacer el trabajo que el demócrata Alcalde no podía hacer.'

# %%
print(traduccion.extra_data)
# Out:
# {'translation': [['La Guardia Nacional ha sido puesto en libertad en Minneapolis para hacer el trabajo que el demócrata Alcalde no podía hacer.', 'The National Guard has been released in Minneapolis to do the job that the Democrat Mayor couldn’t do.', None, None, 0]], 'all-translations': None, 'original-language': 'en', 'possible-translations': [['The Guard National', None, [['La Guardia Nacional', 377, True, False], ['La Guardia Nacional de', 0, True, False], ['A la Guardia Nacional', 0, True, False], ['De la Guardia Nacional', 0, True, False]], [[0, 18]], 'The National Guard has been released in Minneapolis to do the job that the Democrat Mayor couldn’t do.', 0, 3], ['has', None, [['ha', 805, True, False], ['haya', 0, True, False], ['se ha', 0, True, False], ['han', 0, True, False], ['se', 0, True, False]], [[19, 22]], None, 3, 4], ['been released', None, [['sido puesto en libertad', 950, True, False], ['sido liberado', 16, True, False], ['sido lanzado', 5, True, False], ['ha liberado', 0, True, False], ['fue liberado', 0, True, False]], [[23, 36]], None, 4, 8], ['in Minneapolis', None, [['en Minneapolis', 767, True, False], ['en Mineápolis', 0, True, False], ['de Minneapolis', 0, True, False], ['en Miniápolis', 0, True, False]], [[37, 51]], None, 8, 10], ['to do the job', None, [['para hacer el trabajo', 814, True, False], ['que hacer el trabajo', 0, True, False], ['de hacer el trabajo', 0, True, False], ['hacer el trabajo', 0, True, False], ['para realizar el trabajo', 0, True, False]], [[52, 65]], None, 10, 14], ['that the', None, [['que el', 895, True, False], ['que la', 3, True, False], ['porque el', 0, True, False], ['de que el', 0, True, False], ['de que la', 0, True, False]], [[66, 74]], None, 14, 16], ['Democrat', None, [['demócrata', 824, True, False], ['Democrat', 0, True, False], ['de Demócrata', 0, True, False], ['demócratas', 0, True, False], ['demócrata de', 0, True, False]], [[75, 83]], None, 16, 17], ['Mayor', None, [['Alcalde', 809, True, False], ['Mayor', 110, True, False], ['alcaldesa', 0, True, False], ['El alcalde', 0, True, False], ['Alcalde de', 0, True, False]], [[84, 89]], None, 17, 18], ['not could do .', None, [['no podía hacer.', 502, True, False]], [[90, 102]], None, 18, 22]], 'confidence': 1.0, 'possible-mistakes': ['The National Guard has been released in Minneapolis to do the job that the Democrat Mayor <b><i>couldn&#39;t</i></b> do.', "The National Guard has been released in Minneapolis to do the job that the Democrat Mayor couldn't do.", [1], None, None, False], 'language': [['en'], None, [1.0], ['en']], 'synonyms': None, 'definitions': None, 'examples': None, 'see-also': None}

# %%
idioma = translator.detect('nein.')
idioma.lang
# Out:
# 'de'
