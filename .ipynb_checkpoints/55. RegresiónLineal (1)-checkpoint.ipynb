# %% [markdown]
# # Regresión Lineal
#
# #### El objetivo de la regresión lineal es modelar la relación entre una o múltiples características y **una variable de destino continua**

# %% [markdown]
# # Regresión Lineal simple
#
# #### El objetivo de una regresión lineal simple (univariada) es modelar una relación entre una característica simple (variable explicativa x) y una respuesta de valor continuo (variable de destino y)
#
# La ecuación de un modelo lineal con una variable explicativa se define del siguiente modo:
#
# $$ y = w_o + w_1x $$
#
# Donde el peso $w_0$ representa el eje y interceptado y $w_1$ es el coeficiente ponderado de la variable explicativa. **El objetivo es aprender los pesos de la ecuación lineal anterior para describir la relación entre la variable explicativa y la variable de destino.**
#
#
# En otras palabras la regresión lineal se puede definir como la búsqueda de la recta que mejor se ajuste a través de puntos de muestra.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# La línea que se ajusta a los puntos se conoce como **recta de regresión** y las líneas verticales que van de la recta de regresión a los puntos de muestra se conocen como **offsets o residuos**

# %% [markdown]
# # ¿Como se va ajustar la recta?
#
# - Existen variados métodos para ajustar la recta a los puntos, para el ejercicio actual vamos a utilizar le modelo de sklearn: LinearRegression(), el cual busca minimizar la suma de los errores al cuadrado

# %% [markdown]
# #### Lo que busca este método es minimizar los parametros $w_0$ y $w_1$ .
#
# Para encontrar el valor de $w_1$ utilizamos la siguiente ecuación:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Para encontrar el valor inicial de $w_0$ utilizamos la siguiente ecuación:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Evaluar el resultado

# %% [markdown]
# #### Existen diferentes métodos para evaluar el error entre la predicción y el valor real.
#
# **1. Mean Absolute Error.** Es el valor absoluto de los errores, es la métrica más fácil de entender y la podemos interpretar como el promedio del error.
#
# $$ MAE = \frac{1}{n}\sum_{i=1}^{n} \left | y_i - \widehat{y_i} \right | $$
#
# **2. Mean Squared Error.** Es el promedio del error cuadrado y se utiliza cuando se tienen grandes errores. Esto se debe a que el término al cuadrado aumenta exponencialmente los errores más grandes en comparación con los más pequeños.
#
# $$ MSE = \frac{1}{n}\sum_{i=1}^{n}  (y_i - \widehat{y_i})^2 $$
#
# **3. Root Mean Squared Error.** Es el más popular de las métricas de evaluacion para regresiones porque se puede interpretar en las mismas unidades que $y$ lo que facilita entender la información que proporciona.
#
# $$ RMSE = \sqrt{\frac{1}{n}\sum_{i=1}^{n}  (y_i - \widehat{y_i})^2} $$
#
#
# **4. Relative Absolute Error (también conocido como: Residual Sum of Square).** Toma el total del error absoluto y lo normaliza al dividirlo por el total del error absoluto de cada uno de los puntos de evaluación.
#
# $$ RAE = \frac{\sum_{i=1}^{n} \left | y_i - \widehat{y_i} \right |}{\sum_{i=1}^{n} \left | y_i - \overline{y_i} \right |}$$
#
# **5. Relative Squared Error.** Es muy similiar al RAE pero su utilización se acerca más a la comunidad de data science debido a que se utiliza para calcular $R^2$
#
# $$ RSE = \frac{\sum_{i=1}^{n}  (y_i - \widehat{y_i})^2 }{\sum_{i=1}^{n}  (y_i - \overline{y_i})^2 } $$
#
# **6. R squared.** No es un error por si mismo, pero es la métrica más popular en el mundo de data science para evaluar el rendimiento de un modelo de regresión. Representa que tan cerca están las predicciones de los valores reales.
#
# Entre más alto el valor de $R^2$, mejor rendimiento tiene el modelo. El valor máximo que puede alcanzar es 1.
#
# $$ R^2 = 1- RSE $$

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("FuelConsumptionCo2.csv") #Características de autos y emisión de CO2

# %% [markdown]
# ### FuelConsumption.csv:
#
# - **MODELYEAR**: 2014
# - **MAKE**: Acura
# - **MODEL**: ILX
# - **VEHICLE CLASS**: SUV
# - **ENGINE SIZE**: 4.7
# - **CYLINDERS**: 6
# - **TRANSMISSION**: A6
# - **FUEL CONSUMPTION in CITY(L/100 km)**: 9.9
# - **FUEL CONSUMPTION in HWY (L/100 km)**:8.9
# - **FUEL CONSUMPTION COMB (L/100 km)**: 9.2
# - **CO2 EMISSIONS (g/km)**: 182   --> low --> 0

# %%
df
# Out:
#       MODELYEAR   MAKE       MODEL    VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0          2014  ACURA         ILX         COMPACT         2.0          4
# 1          2014  ACURA         ILX         COMPACT         2.4          4
# 2          2014  ACURA  ILX HYBRID         COMPACT         1.5          4
# 3          2014  ACURA     MDX 4WD     SUV - SMALL         3.5          6
# 4          2014  ACURA     RDX AWD     SUV - SMALL         3.5          6
# ...         ...    ...         ...             ...         ...        ...
# 1062       2014  VOLVO    XC60 AWD     SUV - SMALL         3.0          6
# 1063       2014  VOLVO    XC60 AWD     SUV - SMALL         3.2          6
# 1064       2014  VOLVO    XC70 AWD     SUV - SMALL         3.0          6
# 1065       2014  VOLVO    XC70 AWD     SUV - SMALL         3.2          6
# 1066       2014  VOLVO    XC90 AWD  SUV - STANDARD         3.2          6
#
#      TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# ...

# %%
df.shape
# Out:
# (1067, 13)

# %%
sns.distplot(df["CO2EMISSIONS"]) #Histograma de la emisión de C02

# %%
sns.boxplot(df["CO2EMISSIONS"])

# %% [markdown]
# # Vamos a gráficar las siguientes características vs la emisión de CO2:
#
# - ENGINE SIZE
# - CYLINDERS
# - TRANSMISSION
# - FUEL CONSUMPTION in CITY(L/100 km)
# - FUEL CONSUMPTION in HWY (L/100 km)
# - FUEL CONSUMPTION COMB (L/100 km)

# %%
for i in ["ENGINESIZE","CYLINDERS", "TRANSMISSION", "FUELCONSUMPTION_CITY", "FUELCONSUMPTION_HWY","FUELCONSUMPTION_COMB"]:
    sns.scatterplot(df[i] ,df.CO2EMISSIONS, color="r")
    plt.show()

# %% [markdown]
# # Vamos hacer una regresión lineal con la variable ENGINE SIZE

# %% [markdown]
# **1. Primer paso tenemos que seleccionar nuestra variable explicativa y variable destino:**

# %%
df[["ENGINESIZE", "CO2EMISSIONS"]]
# Out:
#       ENGINESIZE  CO2EMISSIONS
# 0            2.0           196
# 1            2.4           221
# 2            1.5           136
# 3            3.5           255
# 4            3.5           244
# ...          ...           ...
# 1062         3.0           271
# 1063         3.2           264
# 1064         3.0           271
# 1065         3.2           260
# 1066         3.2           294
#
# [1067 rows x 2 columns]

# %%
X = np.array(df[['ENGINESIZE']])
y = np.array(df[['CO2EMISSIONS']])

# %%
X
# Out:
# array([[2. ],
#        [2.4],
#        [1.5],
#        ...,
#        [3. ],
#        [3.2],
#        [3.2]])

# %%
np.array(df[['ENGINESIZE']])
# Out:
# array([[2. ],
#        [2.4],
#        [1.5],
#        ...,
#        [3. ],
#        [3.2],
#        [3.2]])

# %% [markdown]
# **2. Dividir el dataset en 70% entrenamiento (train) y 30% prueba (test)**

# %%
def operaciones(a,b): #Ejemplo similiar a la función de train_test_split
    return a+b,a-b

# %%
suma, resta = operaciones(10,5)
print(suma)
print(resta)
# Out:
# 15
# 5

# %%
#Utilizamos la función train_test_split de sklearn
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# %%
print("tamaño del conjunto de entrenamiento: ", X_train.shape, "Tamaño del conjunto de prueba: ", X_test.shape)
# Out:
# tamaño del conjunto de entrenamiento:  (746, 1) Tamaño del conjunto de prueba:  (321, 1)

# %% [markdown]
# **3. Entrenar el algoritmo de regresión lineal**

# %%
regresion_lineal = linear_model.LinearRegression()
regresion_lineal.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Encontramos los coeficientes de la recta  
print ('w_1: ', regresion_lineal.coef_)
print ('w_0: ',regresion_lineal.intercept_)
# Out:
# w_1:  [[38.92382581]]
# w_0:  [125.91549459]

# %%
sns.scatterplot(X_train.flatten(),y_train.flatten(), color="magenta") #entrenamiento
sns.scatterplot(X_test.flatten(),y_test.flatten(), color="green") #prueba 
plt.plot(X_train, regresion_lineal.coef_[0][0]*X_train + regresion_lineal.intercept_[0], '-b')
plt.show()

# %% [markdown]
# #### .predict()
#
# Como parametro de entrada el conjunto X_test y queremos que prediga que valores ($\widehat{y}$) debería de tener cada elemento

# %%
yhat = regresion_lineal.predict(X_test)

for i,j in zip(yhat,y_test):
    print("Predicción: ",i, "Valor real: ",j)
# Out:
# Predicción:  [188.64141637] Valor real:  [191]
# Predicción:  [269.78403155] Valor real:  [283]
# Predicción:  [188.64141637] Valor real:  [179]
# Predicción:  [188.64141637] Valor real:  [177]
# Predicción:  [320.01517427] Valor real:  [338]
# Predicción:  [331.60697644] Valor real:  [270]
# Predicción:  [265.92009749] Valor real:  [283]
# Predicción:  [223.41682288] Valor real:  [239]
# Predicción:  [262.05616343] Valor real:  [253]
# Predicción:  [331.60697644] Valor real:  [292]
# Predicción:  [265.92009749] Valor real:  [269]
# Predicción:  [296.83156994] Valor real:  [338]
# Predicción:  [196.36928448] Valor real:  [177]
# Predicción:  [265.92009749] Valor real:  [237]
# Predicción:  [358.65451483] Valor real:  [327]
# Predicción:  [262.05616343] Valor real:  [242]
# Predicción:  [265.92009749] Valor real:  [262]
# Predicción:  [320.01517427] Valor real:  [315]
# Predicción:  [262.05616343] Valor real:  [172]
# Predicción:  [331.60697644] Valor real:  [344]
# ...

# %%
from sklearn.metrics import mean_squared_error, r2_score
mean_squared_error(yhat,y_test)
# Out:
# 945.9870218472724

# %%
r2_score(y_test,yhat)
# Out:
# 0.770049100257959
