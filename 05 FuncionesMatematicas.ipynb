# %%
import math 
import random
import numpy as np

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm

# %% [markdown]
# # Función de Schwefel

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Vamos a graficar la función de schwefel
fig = plt.figure(figsize = (10,8))
ax = fig.gca(projection='3d')
# Valores del -100 al 100, con paso de 0.1
X = np.arange(-100, 100, 0.1)
Y = np.arange(-100, 100, 0.1)
X, Y = np.meshgrid(X, Y) #Creación de la malla 

###########################  ECUACIÓN ########################################
Z = 418.9829 * 2 - (X*np.sin(np.sqrt(abs(X)))+ Y*np.sin(np.sqrt(abs(Y)))) ##
##############################################################################

# Plot de la superficie
ax.plot_surface(X, Y, Z)

# %% [markdown]
# # Ejercicios

# %% [markdown]
# ## Encontrar el valor de z para las coordenadas (o valores de X y Y), que se muestran en la tabla, para cada una de las funciones.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1. Función Gramacy & Lee
# - **Nota:** Solo utilizar los valores de x

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import math
x_lista = (10,15,25,35,45)
for x in x_lista:
    fx = (math.sin(10*math.pi*x) / (2*x)) + (x-1)**4
    print(fx)
# Out:
# 6561.0
# 38416.0
# 331776.0
# 1336336.0
# 3748096.0

# %% [markdown]
# ## 2. Función McCormick

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x_lista = (10,15,25,35,45)
y_lista = (15,20,30,40,50)

for x,y in zip(x_lista,y_lista):
    fx  = (math.sin(x+y)) + ((x-y)**2) - (1.5*x) + (2.5*y) +1
    print("%.2f"%fx)
# Out:
# 48.37
# 53.07
# 62.50
# 73.11
# 84.18

# %% [markdown]
# ## 3. Función Bohachevsky

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x_lista = (10,15,25,35,45)
y_lista = (15,20,30,40,50)

# %%
for x,y in zip(x_lista,y_lista):
    fx=(x**2)+(2*y**2)-(0.3*math.cos(3*math.pi*x))-(0.4*math.cos(4*math.pi*y))+0.7
    print(fx)
# Out:
# 550.0000000000001
# 1025.6
# 2425.6
# 4425.6
# 7025.6

# %% [markdown]
# ## 4. Función Drop-Wave

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
for x,y in zip(x_lista,y_lista):
    a= 1+ (math.cos(12*math.sqrt(x**2+y**2)))
    b= (0.5*(x**2+y**2))+2
    fx= -(a/b)
    print(fx)
# Out:
# -0.000570802279717615
# -0.0031093907177148364
# -0.00017139045713936396
# -1.513211997048681e-06
# -6.50615211186921e-06

# %% [markdown]
# ## 5. Función Eggholder

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
for x,y in zip(x_lista,y_lista):
    a=(y+47)
    b=(math.sqrt(abs(y+(x/2)+47)))
    c=(math.sqrt(abs(x-(y+47))))
    fx=(-a*math.sin(b))-(x*math.sin(c))
    print(fx)
# Out:
# -66.63075370210524
# -59.76119187795656
# -17.263626455350543
# 34.260153075696024
# 60.784817994636924

# %% [markdown]
# ## 6. Función Holder Table

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
for x,y in zip(x_lista,y_lista):
    a=abs(1-((math.sqrt(x**2+y**2))/(math.pi)))
    b=math.sin(x)*math.cos(y)*math.exp(a)
    fx=-abs(b)
    print(fx)
# Out:
# -47.21909111092168
# -278.97438807293287
# -1879.8270994877523
# -2338777.8014454693
# -601531096.3270379

# %%
math.exp(2)
# Out:
# 7.38905609893065
